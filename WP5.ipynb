# %%
import json
import math

import time
import numpy as np

from scipy import interpolate
from scipy.interpolate import interpolate

from matplotlib import pyplot as plt

# %% [markdown]
# $\textbf{Plant}$
#
# This class which provides an interface to manage the binning of a trajectory of states and control inputs to obtain the conditional pmf $f(x_k|x_{k-1}, u_k)$ of the plant.

# %%
class Plant:

    def __init__(self, x_max, x_min, u_max, u_min, x_discr, u_discr):
        # Bounds for u and x
        self.x_max = x_max
        self.x_min = x_min
        self.u_max = u_max
        self.u_min = u_min

        # Amount of bins (resolution) for u and x
        self.x_discr = x_discr
        self.u_discr = u_discr

        # Discretization step for x and u
        self.x_step = (self.x_max - self.x_min)/self.x_discr
        self.u_step = (self.u_max - self.u_min)/self.u_discr
    
        self.x_axis = [self.x_min + (i+0.5)*self.x_step for i in range(self.x_discr)]
        self.u_axis = [self.u_min + (j+0.5)*self.u_step for j in range(self.u_discr)]  

        self.full_joint = np.zeros((self.x_discr, self.u_discr, self.x_discr)) #Initializing f(x_k, u_k, x_{k-1}) (3D array)
        self.reduced_joint = np.zeros((self.x_discr, self.u_discr)) #Initializing f(u_k, x_{k-1}) (2D array)
        self.f_x = np.zeros((self.x_discr, self.u_discr, self.x_discr)) #Initializing f(x_k| u_k, x_{k-1}) (3D array)

    def getXdiscr(self):
        return self.x_discr

    def getUdiscr(self):
        return self.u_discr

    def getXmin(self):
        return self.x_min

    def getUmin(self):
        return self.u_min

    def getXmax(self):
        return self.x_max

    def getUmax(self):
        return self.u_max

    def getXstep(self):
        return self.x_step

    def getUstep(self):
        return self.u_step

    def getXaxis(self):
        return self.x_axis

    def getUaxis(self):
        return self.u_axis

    def getPlant(self, x, u):
        # Function that handles the binning of a trajectory
        # Given a history for the state and the input (ie two lists), browses each list and increments the appropriate histogram bins 
        for i in range(len(x)-1): #N-1 iterations (since we study consecutive pairs of states, one iteration less than the number of states)
            xkm1 = x[i] #x_{k-1}
            xk = x[i+1] #x_k
            uk = u[i+1] #u_k

            #Calculating the index from the min value and the discretization step
            indXkm1 = int((xkm1 - self.x_min)//self.x_step)
            indXk = int((xk - self.x_min)//self.x_step)
            indUk = int((uk - self.u_min)//self.u_step)
            self.full_joint[indXkm1][indUk][indXk] += 1 #Updating the full joint 'pmf'
            self.reduced_joint[indXkm1][indUk] += 1 #Updating the partial 'pmf'

        for i in range(self.x_discr): #For each x_{k-1}
            for j in range(self.u_discr): #For each u_k
                for k in range(self.x_discr): #For each x_k
                    if self.full_joint[i][j][k] == 0: #Failsafe to avoid dividing by zero
                        self.f_x[i][j][k] = 0 #If we've never encountered this state, let the conditionnal value be zero
                    else:
                        self.f_x[i][j][k] = self.full_joint[i][j][k]/self.reduced_joint[i][j] #Divide the full joint by the partial joint

# %% [markdown]
# $\textbf{GaussianPlant}$
#
# This class extends the class Plant and provides an interface to get the conditional pmf of the plant, using the explicit formula of the Gaussian.
#
# The $\textit{GaussianPlant}$ class has been used to obtain a Gaussian conditional pmf $f(x_k|x_{k-1}, u_k)$ of the plant, in the form of an entry of $[mean, std]$, usable in an algorithm of control from demonstration that employes analytical computational techniques, implemented in the $\textit{AnalyticalSolver}$ class, or in the form of a normal Gaussian distribution that can be used in a control from demonstration algorithm that uses numerical computational techniques.

# %%
class GaussianPlant(Plant):

    def __init__(self, x_max, x_min, u_max, u_min, x_discr, u_discr, a, b, sigma, mode="analytic"):
        super().__init__(x_max, x_min, u_max, u_min, x_discr, u_discr)
        self.sigma = sigma
        self.a = a
        self.b = b
        self.mode = mode
        

    def getPlant(self, x = None, y = None):
        # Function for getting the plant (f_x or g_x) from the parameters.
        # The arguments are the linear parameters for the mean and the std.
        # The Gaussians are simply coded as [mean, std] to simplify calculations
        if self.mode == "analytic":
            self.f_x = np.zeros((self.x_discr, self.u_discr, 2)) # Initializing the empty array
        for i in range(self.x_discr): # Iterating over the state space for x_{k-1}
            x_km1 = self.x_min + (i+0.5)*self.x_step # Calculating x_{k-1}
            for j in range(self.u_discr): # Iterating over the action space for u_k
                u_k = self.u_min + (j+0.5)*self.u_step # Calculating u_k
                mu = self.a*x_km1 + self.b*u_k # Calculating the average of the Gaussian
                if self.mode == "analytic":
                    self.f_x[i][j] = [mu, self.sigma] # Adding the Gaussian in [mean, std] form to the array
                else:
                    self.f_x[i][j] = self.sample_gaussian(mu, self.sigma, self.x_axis)
        return(self.f_x)

    def sample_gaussian(self, mu, sigma, Ax):
        # Where Ax is the horizontal axis
        pmf = [0]*len(Ax) # Initializing the pmf
        for i in range(len(Ax)): # Iterating over the state space to calculate the elements of the pmf
            pmf[i] = np.exp(-0.5*((Ax[i]-mu)/sigma)**2)  # Using the explicit formula for the Gaussian
                                                         # The multiplicative factor is omitted as the pmf will be normalized
        S = np.sum(pmf) # Calculating the sum for normalization
        return([x/S for x in pmf])

# %% [markdown]
# $\textbf{NumericalSolver}$
#
# This class provides an interface for carrying out control from demonstration using numerical computational techniques and it is capable of receiving any type of probability distribution as input.

# %%
class NumericalSolver:

    def __init__(self, f, g, g_u):
        self.f = f # Plant object of the agent
        self.g = g # Plant object of the demonstrator
        self.g_u = g_u # TargetPolicy object


    def DKL(self, f, g):
        # Kullback-Leibler divergence between two arrays, they have to be pmfs (ie histograms that sum to 1)
        return(np.sum([f[i]*math.log(f[i]/g[i]) for i in range(len(f)) if f[i]!=0 and g[i]!= 0]))

    def runFPD(self, xStart, tHor=0):

        x_discr = self.f.getXdiscr()
        u_discr = self.f.getUdiscr()

        f_x = self.f.getPlant()
        g_x = self.g.getPlant()

        # Runs the control from demos algorithm, assuming the agent is at state xStart (given as an index!) with a time horizon tHor
        # Initializing zero gamma function
        gamma = np.zeros(x_discr)
        # If time horizon is greater than 0 we consider the states from the min between (xStart + time horizon -1) and 
        # (d_discr-2) (in order to not exceed the dimension of the array) to (xStart + 1)
        if tHor > 0: 
            stateAtTime = list(range(min(xStart + tHor-1, x_discr - 2), xStart, -1))
        # Else we don't take into account the future states, but we consider only the next time step
        else: 
            stateAtTime = [] 
        
        # We calculate gamma from xStart + time horizon to xStart + 1
        for xk, uk in zip(stateAtTime, stateAtTime):
            # We initialize an auxiliary array, which we will use to calculate gamma_k(x_k)
            gammaArray = np.zeros(u_discr)
            # We get f(x_{k+1}|x_k,u_{k+1})
            plant = f_x[xk][uk+1] 
            # We get g(x_{k+1}|x_k,u_{k+1})
            target_plant = g_x[xk][uk+1]
            # We build the array with the exp of the numeric DKL of the 'future' plants
            gammaArray[uk+1] = np.exp(-self.DKL(plant, target_plant))
            # Finally we calculate gamma, which is the log of the expectation of our auxiliary array
            gamma[xk] = np.log(np.dot(self.g_u.target_policy(xk),gammaArray)) 
        
        # Previous state x_(k-1)
        xkm1 = xStart  
        policy = np.zeros(u_discr)
        # We extract the corresponding target policy, g(u_k|x_{k-1}) 
        target_pol = self.g_u.target_policy(xkm1) 
        for u in range(u_discr): 
            # We get f(x_{k}|x_{k - 1}, u_k)
            plant = f_x[xkm1][u]
            # We get g(x_{k}|x_{k - 1}, u_k)
            target_plant = g_x[xkm1][u]
            # We sample plant for expectations
            policy[u] = target_pol[u]*np.exp(-self.DKL(plant, target_plant) + np.dot(plant,gamma))
        # We calculate the integral
        S = np.sum(policy)
        # We return the normalized result
        return([elt/S for elt in policy]) 

    def closedLoop(self, tHor=0):

        position = []
        speed = []
        x = 0

        x_discr = self.f.getXdiscr()
        u_discr = self.f.getUdiscr()

        x_step = self.f.getXstep()
        u_step = self.f.getUstep()

        u_min = self.f.getUmin()
        x_min = self.f.getXmin()

        f_x = self.f.getPlant()

        while(x < (x_discr*800)/1500):
            policy = self.runFPD(x, tHor) # We get the optimal policy
            u = np.random.choice(range(u_discr), p=policy) # We choose a random index u from the policy according to the distribution of the policy
            plant = f_x[x][u] # We get the conditional pmf of x_k: f(x_k|x_{k-1}, u_k)
            # We get the new state from the plant
            x = np.random.choice(range(x_discr), p=plant)
            x = max(x, 0)

            # We compute the value of state from the state index
            trueX = x_min + x_step*x

            # We compute the value of input from the input index
            trueU = u_min + u_step*u
            
            position.append(trueX)
            speed.append(trueU)

            print("Speed: " + str(trueU) + " km/h")
            print("New position: " + str(trueX) + " m")
    
        plt.figure(figsize=(8, 6), dpi=80)
        plt.subplot(2,1,1)
        plt.title("Simulation of the closed loop")
        plt.ylabel(r'Position $(m)$', fontsize=12)
        plt.plot(position)
        
        plt.subplot(2,1,2)
        plt.xlabel(r'Time $(s)$', fontsize=12)
        plt.ylabel(r'Velocity $(km/h)$', fontsize=12)
        plt.plot(speed)
        plt.show()

# %% [markdown]
# $\textbf{AnalyticalSolver}$
#
# This class provides an interface to perform the control from demonstration using analytic computing techniques, in particular using the explicit formula of the Gaussian.
#
# The pmf of the agent and of the demonstrator have to be Gaussian distribution.

# %%
class AnalyticalSolver(NumericalSolver):

    def __init__(self, f, g, g_u):
        super().__init__(f, g, g_u)

    def DKL(self, f, g):
        mu1 = f[0] #Extracting means
        mu2 = g[0]
        sigma1 = f[1] #Extracting stds
        sigma2 = g[1]
        
        el1 = math.log(sigma1/sigma2) # Calculating the sub-elements of the formula
        el2 = sigma1*sigma1 + (mu1-mu2)*(mu1-mu2)
        el3 = 2*sigma2*sigma2
        
        return(el1 + el2/el3 - 0.5)

    def runFPD(self, xStart, tHor=0):

        x_discr = self.f.getXdiscr()
        u_discr = self.f.getUdiscr()

        f_x = self.f.getPlant()
        g_x = self.g.getPlant()

        #Runs the control from demos algorithm, assuming the agent is at state xStart (given as an index!) with a time horizon tHor
        #Initializing zero gamma function
        gamma = np.zeros(x_discr)
        # If time horizon is greater than 0 we consider the states from the min between (xStart + time horizon -1) and
        # (d_discr-2) (in order to not exceed the dimension of the array) to (xStart + 1)
        if tHor >0: 
            stateAtTime = list(range(min(xStart + tHor-1, x_discr - 2), xStart, -1))
        # Else we don't take into account the future states, but we consider only the next time step
        else: 
            stateAtTime = [] 
        
        # We calculate gamma from xStart + time horizon to xStart + 1
        for xk, uk in zip(stateAtTime, stateAtTime):
            # We initialize an auxiliary array, which we will use to calculate gamma_k(x_k)
            gammaArray = np.zeros(u_discr)
            # We get f(x_{k+1}|x_k,u_{k+1}) in [mean, std] form
            plant = f_x[xk][uk+1]
            # We get g(x_{k+1}|x_k,u_{k+1}) in [mean, std] form
            target_plant = g_x[xk][uk+1]
            # We build the array with the exp of the analytic DKL of the 'future' plants
            gammaArray[uk+1] = np.exp(-self.DKL(plant, target_plant))
            # Finally we calculate gamma, which is the log of the expectation of our auxiliary array
            gamma[xk] = np.log(np.dot(self.g_u.target_policy(xk),gammaArray)) 
        
        # Previous state x_(k-1)
        xkm1 = xStart  
        policy = np.zeros(u_discr)
        # We extract the corresponding target policy, g(u_k|x_{k-1})
        target_pol = self.g_u.target_policy(xkm1)
        for u in range(u_discr):
            # We get f(x_{k}|x_{k - 1}, u_k)
            plant = f_x[xkm1][u]
            # We get g(x_{k}|x_{k - 1}, u_k)
            target_plant = g_x[xkm1][u]
            # We sample plant for expectations
            policy[u] = target_pol[u]*np.exp(-self.DKL(plant, target_plant) + np.dot(self.f.sample_gaussian(plant[0],plant[1], self.f.getXaxis()), gamma))
        # We calculate the integral
        S = np.sum(policy)
        # We return the normalized result
        return([elt/S for elt in policy]) 

    def closedLoop(self, tHor=0):

        position = []
        speed = []
        x = 0

        x_discr = self.f.getXdiscr()
        u_discr = self.f.getUdiscr()

        x_step = self.f.getXstep()
        u_step = self.f.getUstep()

        u_min = self.f.getUmin()

        f_x = self.f.getPlant()

        while(x < (x_discr*800)/1500):
            policy = self.runFPD(x, tHor) # We get the optimal policy
            u = np.random.choice(range(u_discr), p=policy) # We choose a random index u from the policy according to the distribution of the policy
            plant = f_x[x][u] # We get the conditional pmf of x_k: f(x_k|x_{k-1}, u_k)
            # We get the new state from the plant
            trueX = np.random.normal(plant[0],plant[1])
            x = round(trueX/x_step)

            x = max(x, 0)

            # We compute the value of input from the input index
            trueU = u_min + u_step*u
            
            position.append(trueX)
            speed.append(trueU)

            print("Speed: " + str(trueU) + " km/h")
            print("New position: " + str(trueX) + " m")
    
        plt.figure(figsize=(8, 6), dpi=80)
        plt.subplot(2,1,1)
        plt.title("Simulation of the closed loop")
        plt.ylabel(r'Position $(m)$', fontsize=12)
        plt.plot(position)
        
        plt.subplot(2,1,2)
        plt.xlabel(r'Time $(s)$', fontsize=12)
        plt.ylabel(r'Velocity $(km/h)$', fontsize=12)
        plt.plot(speed)
        plt.show()

# %% [markdown]
# $\textbf{TargetPolicy}$
#
# This class provides an interface to obtain the probability distribution of the control input given the previous state.

# %%
class TargetPolicy:

    def __init__(self, g, fmean, fstd):
        self.g = g
        self.g_u = [fmean(self.g.getXaxis()), fstd(self.g.getXaxis())]

    def target_policy(self, indx):
        return(self.g.sample_gaussian(self.g_u[0][indx], self.g_u[1][indx], self.g.getUaxis()))

# %% [markdown]
# $\textbf{System parameters}$

# %%
#Bounds for u (velocity) and x (distance)
v_min = 15
v_max = 85

d_min = 0
d_max = 1500

#Amount of bins (resolution) for u and x
v_discr = 100
d_discr = 100

# %%
#Parameters for f(x_k|x_{k-1},u_k)
a_c = 0.982
b_c = 0.2591
sigma_c = 13.059

#Parameters for g(x_k|x_{k-1},u_k)
a_e = 0.9811
b_e = 0.2723
sigma_e = 8.811

# %% [markdown]
# $\textbf{Target policy}$

# %%
# Target policy
f1 = open('train_mean.json')
f2 = open('train_std.json')

means = json.load(f1)
std = json.load(f2)

# means["x"] and means["y"] are arrays of values used to approximate some function g(u_k|x_{k_1}). 
fmean = interpolate.interp1d(means['x'],means['y'], fill_value="extrapolate")
fstd = interpolate.interp1d(std['x'],std['y'], fill_value="extrapolate")

# %%
f = GaussianPlant(d_max, d_min, v_max, v_min, d_discr, v_discr, a_c, b_c, sigma_c, "analytic")
g = GaussianPlant(d_max, d_min, v_max, v_min, d_discr, v_discr, a_e, b_e, sigma_e, "analytic")
target_policy = TargetPolicy(g, fmean, fstd)

# %% [markdown]
# $\textbf{Closed loop simulation using analytic solver}$

# %%
solver = AnalyticalSolver(f, g, target_policy)
solver.closedLoop()
# Out:
# Speed: 57.699999999999996 km/h
# New position: 17.706845240029686 m
# Speed: 54.9 km/h
# New position: 18.82443651041211 m
# Speed: 50.699999999999996 km/h
# New position: 28.070221953667797 m
# Speed: 55.599999999999994 km/h
# New position: 33.089645151543756 m
# Speed: 50.699999999999996 km/h
# New position: 58.63018072120786 m
# Speed: 55.599999999999994 km/h
# New position: 83.29463617762018 m
# Speed: 56.3 km/h
# New position: 97.69023380932018 m
# Speed: 52.099999999999994 km/h
# New position: 120.38492036003964 m
# Speed: 52.8 km/h
# New position: 119.23810335831936 m
# Speed: 59.8 km/h
# New position: 139.96463219854266 m
# Speed: 58.4 km/h
# New position: 149.71551105159526 m
# Speed: 58.4 km/h
# New position: 194.95756585194923 m
# Speed: 57.699999999999996 km/h
# New position: 216.5176908926681 m
# Speed: 50.0 km/h
# New position: 248.09555947199715 m
# Speed: 50.0 km/h
# New position: 274.78531102431464 m
# Speed: 52.099999999999994 km/h
# New position: 290.15292019933776 m
# Speed: 51.4 km/h
# New position: 305.22137337028624 m
# Speed: 54.9 km/h
# New position: 333.08264720927514 m
# Speed: 49.3 km/h
# New position: 331.93168704779083 m
# Speed: 47.9 km/h
# New position: 336.2077051979062 m
# Speed: 48.599999999999994 km/h
# New position: 368.9532997923817 m
# Speed: 57.699999999999996 km/h
# New position: 362.390801019568 m
# Speed: 61.199999999999996 km/h
# New position: 356.4822402610816 m
# Speed: 53.5 km/h
# New position: 375.32319155477825 m
# Speed: 56.3 km/h
# New position: 377.8107265294499 m
# Speed: 64.69999999999999 km/h
# New position: 398.4579999087433 m
# Speed: 47.9 km/h
# New position: 396.94933238659456 m
# Speed: 52.8 km/h
# New position: 409.7576400951776 m
# Speed: 52.8 km/h
# New position: 429.17791923697246 m
# Speed: 68.9 km/h
# New position: 451.01703311865003 m
# Speed: 58.4 km/h
# New position: 474.57541316464153 m
# Speed: 50.699999999999996 km/h
# New position: 487.22283091450123 m
# Speed: 57.0 km/h
# New position: 506.93307778089996 m
# Speed: 51.4 km/h
# New position: 519.3570454820024 m
# Speed: 66.1 km/h
# New position: 542.1031921371498 m
# Speed: 54.9 km/h
# New position: 563.4621296507522 m
# Speed: 54.199999999999996 km/h
# New position: 573.291185736213 m
# Speed: 48.599999999999994 km/h
# New position: 586.3370110390682 m
# Speed: 50.0 km/h
# New position: 575.349578852396 m
# Speed: 48.599999999999994 km/h
# New position: 585.0191249489457 m
# Speed: 50.0 km/h
# New position: 592.3077563077885 m
# Speed: 47.9 km/h
# New position: 573.0006986164572 m
# Speed: 50.0 km/h
# New position: 593.9697444842834 m
# Speed: 47.9 km/h
# New position: 604.3979068417179 m
# Speed: 47.199999999999996 km/h
# New position: 626.610043082123 m
# Speed: 50.699999999999996 km/h
# New position: 642.3569253109358 m
# Speed: 36.7 km/h
# New position: 654.8672585265826 m
# Speed: 57.0 km/h
# New position: 669.6606924649216 m
# Speed: 50.699999999999996 km/h
# New position: 668.9527004789502 m
# Speed: 41.599999999999994 km/h
# New position: 687.7800978920677 m
# Speed: 40.9 km/h
# New position: 673.3723246545378 m
# Speed: 44.4 km/h
# New position: 675.2616666635101 m
# Speed: 50.0 km/h
# New position: 675.4405807048649 m
# Speed: 59.8 km/h
# New position: 698.298002872999 m
# Speed: 55.599999999999994 km/h
# New position: 712.5391141349835 m
# Speed: 47.199999999999996 km/h
# New position: 714.7254883983701 m
# Speed: 51.4 km/h
# New position: 703.8395603079853 m
# Speed: 45.099999999999994 km/h
# New position: 684.638087572778 m
# Speed: 47.199999999999996 km/h
# New position: 714.2427337782827 m
# Speed: 55.599999999999994 km/h
# New position: 736.8073663077338 m
# Speed: 52.099999999999994 km/h
# New position: 756.5146148456922 m
# Speed: 48.599999999999994 km/h
# New position: 745.1974565579501 m
# Speed: 43.7 km/h
# New position: 758.099037008208 m
# Speed: 48.599999999999994 km/h
# New position: 752.858712292087 m
# Speed: 51.4 km/h
# New position: 773.2913267775892 m
# Speed: 42.3 km/h
# New position: 782.3322943728629 m
# Speed: 56.3 km/h
# New position: 789.6116105945658 m
# Speed: 40.9 km/h
# New position: 795.3746407999806 m
# Speed: 49.3 km/h
# New position: 792.9362782571349 m
# Speed: 55.599999999999994 km/h
# New position: 816.7875449890308 m

# %% [markdown]
# $\textbf{Closed loop simulation using numeric solver}$

# %%
f = GaussianPlant(d_max, d_min, v_max, v_min, d_discr, v_discr, a_c, b_c, sigma_c, "numeric")
g = GaussianPlant(d_max, d_min, v_max, v_min, d_discr, v_discr, a_e, b_e, sigma_e, "numeric")
target_policy = TargetPolicy(g, fmean, fstd)

# %%
solver = NumericalSolver(f, g, target_policy)
solver.closedLoop()
# Out:
# Speed: 54.199999999999996 km/h
# New position: 15.0 m
# Speed: 58.4 km/h
# New position: 30.0 m
# Speed: 50.699999999999996 km/h
# New position: 15.0 m
# Speed: 52.8 km/h
# New position: 15.0 m
# Speed: 60.5 km/h
# New position: 60.0 m
# Speed: 50.0 km/h
# New position: 75.0 m
# Speed: 49.3 km/h
# New position: 90.0 m
# Speed: 57.699999999999996 km/h
# New position: 105.0 m
# Speed: 60.5 km/h
# New position: 90.0 m
# Speed: 46.5 km/h
# New position: 105.0 m
# Speed: 43.7 km/h
# New position: 90.0 m
# Speed: 50.0 km/h
# New position: 105.0 m
# Speed: 51.4 km/h
# New position: 90.0 m
# Speed: 68.19999999999999 km/h
# New position: 105.0 m
# Speed: 59.8 km/h
# New position: 90.0 m
# Speed: 53.5 km/h
# New position: 90.0 m
# Speed: 52.8 km/h
# New position: 105.0 m
# Speed: 64.0 km/h
# New position: 120.0 m
# Speed: 50.699999999999996 km/h
# New position: 120.0 m
# Speed: 59.099999999999994 km/h
# New position: 120.0 m
# Speed: 54.199999999999996 km/h
# New position: 165.0 m
# Speed: 59.099999999999994 km/h
# New position: 165.0 m
# Speed: 54.9 km/h
# New position: 165.0 m
# Speed: 58.4 km/h
# New position: 195.0 m
# Speed: 57.699999999999996 km/h
# New position: 225.0 m
# Speed: 61.9 km/h
# New position: 240.0 m
# Speed: 49.3 km/h
# New position: 255.0 m
# Speed: 51.4 km/h
# New position: 285.0 m
# Speed: 56.3 km/h
# New position: 300.0 m
# Speed: 59.8 km/h
# New position: 330.0 m
# Speed: 55.599999999999994 km/h
# New position: 360.0 m
# Speed: 60.5 km/h
# New position: 360.0 m
# Speed: 55.599999999999994 km/h
# New position: 360.0 m
# Speed: 61.9 km/h
# New position: 390.0 m
# Speed: 50.699999999999996 km/h
# New position: 420.0 m
# Speed: 55.599999999999994 km/h
# New position: 420.0 m
# Speed: 47.199999999999996 km/h
# New position: 420.0 m
# Speed: 52.099999999999994 km/h
# New position: 405.0 m
# Speed: 53.5 km/h
# New position: 420.0 m
# Speed: 52.8 km/h
# New position: 420.0 m
# Speed: 49.3 km/h
# New position: 450.0 m
# Speed: 62.599999999999994 km/h
# New position: 465.0 m
# Speed: 43.7 km/h
# New position: 480.0 m
# Speed: 50.699999999999996 km/h
# New position: 495.0 m
# Speed: 63.3 km/h
# New position: 495.0 m
# Speed: 60.5 km/h
# New position: 510.0 m
# Speed: 57.0 km/h
# New position: 495.0 m
# Speed: 52.099999999999994 km/h
# New position: 495.0 m
# Speed: 57.699999999999996 km/h
# New position: 510.0 m
# Speed: 53.5 km/h
# New position: 510.0 m
# Speed: 59.099999999999994 km/h
# New position: 510.0 m
# Speed: 53.5 km/h
# New position: 510.0 m
# Speed: 48.599999999999994 km/h
# New position: 495.0 m
# Speed: 44.4 km/h
# New position: 480.0 m
# Speed: 59.8 km/h
# New position: 480.0 m
# Speed: 45.8 km/h
# New position: 480.0 m
# Speed: 50.699999999999996 km/h
# New position: 465.0 m
# Speed: 59.099999999999994 km/h
# New position: 480.0 m
# Speed: 60.5 km/h
# New position: 510.0 m
# Speed: 47.199999999999996 km/h
# New position: 495.0 m
# Speed: 57.699999999999996 km/h
# New position: 495.0 m
# Speed: 50.699999999999996 km/h
# New position: 510.0 m
# Speed: 50.699999999999996 km/h
# New position: 510.0 m
# Speed: 49.3 km/h
# New position: 525.0 m
# Speed: 49.3 km/h
# New position: 540.0 m
# Speed: 59.8 km/h
# New position: 555.0 m
# Speed: 43.0 km/h
# New position: 555.0 m
# Speed: 50.0 km/h
# New position: 540.0 m
# Speed: 61.9 km/h
# New position: 525.0 m
# Speed: 52.8 km/h
# New position: 510.0 m
# Speed: 41.599999999999994 km/h
# New position: 510.0 m
# Speed: 43.7 km/h
# New position: 510.0 m
# Speed: 57.699999999999996 km/h
# New position: 525.0 m
# Speed: 50.0 km/h
# New position: 525.0 m
# Speed: 57.0 km/h
# New position: 495.0 m
# Speed: 54.199999999999996 km/h
# New position: 525.0 m
# Speed: 49.3 km/h
# New position: 555.0 m
# Speed: 49.3 km/h
# New position: 555.0 m
# Speed: 49.3 km/h
# New position: 555.0 m
# Speed: 52.8 km/h
# New position: 540.0 m
# Speed: 45.099999999999994 km/h
# New position: 555.0 m
# Speed: 48.599999999999994 km/h
# New position: 585.0 m
# Speed: 45.8 km/h
# New position: 600.0 m
# Speed: 56.3 km/h
# New position: 600.0 m
# Speed: 52.8 km/h
# New position: 600.0 m
# Speed: 45.8 km/h
# New position: 600.0 m
# Speed: 48.599999999999994 km/h
# New position: 585.0 m
# Speed: 68.9 km/h
# New position: 600.0 m
# Speed: 49.3 km/h
# New position: 600.0 m
# Speed: 56.3 km/h
# New position: 600.0 m
# Speed: 47.9 km/h
# New position: 585.0 m
# Speed: 47.199999999999996 km/h
# New position: 555.0 m
# Speed: 54.9 km/h
# New position: 555.0 m
# Speed: 61.9 km/h
# New position: 540.0 m
# Speed: 45.8 km/h
# New position: 540.0 m
# Speed: 43.7 km/h
# New position: 540.0 m
# Speed: 55.599999999999994 km/h
# New position: 540.0 m
# Speed: 52.099999999999994 km/h
# New position: 540.0 m
# Speed: 57.0 km/h
# New position: 540.0 m
# Speed: 49.3 km/h
# New position: 525.0 m
# Speed: 55.599999999999994 km/h
# New position: 540.0 m
# Speed: 56.3 km/h
# New position: 555.0 m
# Speed: 50.699999999999996 km/h
# New position: 540.0 m
# Speed: 55.599999999999994 km/h
# New position: 540.0 m
# Speed: 54.199999999999996 km/h
# New position: 540.0 m
# Speed: 52.8 km/h
# New position: 525.0 m
# Speed: 63.3 km/h
# New position: 525.0 m
# Speed: 50.0 km/h
# New position: 525.0 m
# Speed: 58.4 km/h
# New position: 525.0 m
# Speed: 47.199999999999996 km/h
# New position: 510.0 m
# Speed: 61.199999999999996 km/h
# New position: 540.0 m
# Speed: 49.3 km/h
# New position: 540.0 m
# Speed: 48.599999999999994 km/h
# New position: 540.0 m
# Speed: 60.5 km/h
# New position: 540.0 m
# Speed: 52.8 km/h
# New position: 555.0 m
# Speed: 49.3 km/h
# New position: 555.0 m
# Speed: 50.699999999999996 km/h
# New position: 570.0 m
# Speed: 46.5 km/h
# New position: 585.0 m
# Speed: 52.8 km/h
# New position: 570.0 m
# Speed: 48.599999999999994 km/h
# New position: 585.0 m
# Speed: 44.4 km/h
# New position: 585.0 m
# Speed: 47.199999999999996 km/h
# New position: 600.0 m
# Speed: 52.8 km/h
# New position: 585.0 m
# Speed: 54.9 km/h
# New position: 585.0 m
# Speed: 57.699999999999996 km/h
# New position: 630.0 m
# Speed: 44.4 km/h
# New position: 615.0 m
# Speed: 52.099999999999994 km/h
# New position: 600.0 m
# Speed: 36.0 km/h
# New position: 600.0 m
# Speed: 46.5 km/h
# New position: 600.0 m
# Speed: 44.4 km/h
# New position: 615.0 m
# Speed: 61.199999999999996 km/h
# New position: 630.0 m
# Speed: 49.3 km/h
# New position: 615.0 m
# Speed: 45.8 km/h
# New position: 615.0 m
# Speed: 50.0 km/h
# New position: 630.0 m
# Speed: 50.0 km/h
# New position: 630.0 m
# Speed: 57.699999999999996 km/h
# New position: 630.0 m
# Speed: 52.099999999999994 km/h
# New position: 630.0 m
# Speed: 56.3 km/h
# New position: 660.0 m
# Speed: 56.3 km/h
# New position: 675.0 m
# Speed: 40.9 km/h
# New position: 675.0 m
# Speed: 46.5 km/h
# New position: 675.0 m
# Speed: 46.5 km/h
# New position: 675.0 m
# Speed: 38.8 km/h
# New position: 660.0 m
# Speed: 47.199999999999996 km/h
# New position: 660.0 m
# Speed: 54.9 km/h
# New position: 675.0 m
# Speed: 47.9 km/h
# New position: 660.0 m
# Speed: 48.599999999999994 km/h
# New position: 675.0 m
# Speed: 47.199999999999996 km/h
# New position: 660.0 m
# Speed: 50.0 km/h
# New position: 630.0 m
# Speed: 50.699999999999996 km/h
# New position: 645.0 m
# Speed: 43.0 km/h
# New position: 660.0 m
# Speed: 56.3 km/h
# New position: 675.0 m
# Speed: 37.4 km/h
# New position: 660.0 m
# Speed: 50.0 km/h
# New position: 675.0 m
# Speed: 52.8 km/h
# New position: 675.0 m
# Speed: 54.9 km/h
# New position: 675.0 m
# Speed: 52.099999999999994 km/h
# New position: 675.0 m
# Speed: 44.4 km/h
# New position: 675.0 m
# Speed: 50.0 km/h
# New position: 690.0 m
# Speed: 53.5 km/h
# New position: 690.0 m
# Speed: 55.599999999999994 km/h
# New position: 705.0 m
# Speed: 53.5 km/h
# New position: 705.0 m
# Speed: 50.0 km/h
# New position: 675.0 m
# Speed: 53.5 km/h
# New position: 675.0 m
# Speed: 49.3 km/h
# New position: 675.0 m
# Speed: 54.9 km/h
# New position: 690.0 m
# Speed: 35.3 km/h
# New position: 690.0 m
# Speed: 58.4 km/h
# New position: 705.0 m
# Speed: 53.5 km/h
# New position: 720.0 m
# Speed: 51.4 km/h
# New position: 705.0 m
# Speed: 54.9 km/h
# New position: 705.0 m
# Speed: 35.3 km/h
# New position: 705.0 m
# Speed: 47.199999999999996 km/h
# New position: 690.0 m
# Speed: 50.0 km/h
# New position: 690.0 m
# Speed: 52.8 km/h
# New position: 720.0 m
# Speed: 47.199999999999996 km/h
# New position: 720.0 m
# Speed: 41.599999999999994 km/h
# New position: 705.0 m
# Speed: 59.8 km/h
# New position: 705.0 m
# Speed: 36.0 km/h
# New position: 690.0 m
# Speed: 45.8 km/h
# New position: 705.0 m
# Speed: 57.0 km/h
# New position: 705.0 m
# Speed: 56.3 km/h
# New position: 705.0 m
# Speed: 49.3 km/h
# New position: 690.0 m
# Speed: 45.099999999999994 km/h
# New position: 690.0 m
# Speed: 40.9 km/h
# New position: 675.0 m
# Speed: 59.8 km/h
# New position: 690.0 m
# Speed: 48.599999999999994 km/h
# New position: 690.0 m
# Speed: 41.599999999999994 km/h
# New position: 675.0 m
# Speed: 38.8 km/h
# New position: 675.0 m
# Speed: 47.199999999999996 km/h
# New position: 690.0 m
# Speed: 44.4 km/h
# New position: 705.0 m
# Speed: 45.8 km/h
# New position: 705.0 m
# Speed: 46.5 km/h
# New position: 690.0 m
# Speed: 52.099999999999994 km/h
# New position: 690.0 m
# Speed: 43.0 km/h
# New position: 690.0 m
# Speed: 50.699999999999996 km/h
# New position: 705.0 m
# Speed: 43.0 km/h
# New position: 705.0 m
# Speed: 52.8 km/h
# New position: 735.0 m
# Speed: 40.9 km/h
# New position: 765.0 m
# Speed: 57.699999999999996 km/h
# New position: 765.0 m
# Speed: 45.8 km/h
# New position: 765.0 m
# Speed: 47.9 km/h
# New position: 750.0 m
# Speed: 49.3 km/h
# New position: 750.0 m
# Speed: 54.9 km/h
# New position: 750.0 m
# Speed: 56.3 km/h
# New position: 750.0 m
# Speed: 50.0 km/h
# New position: 765.0 m
# Speed: 54.199999999999996 km/h
# New position: 750.0 m
# Speed: 56.3 km/h
# New position: 765.0 m
# Speed: 52.8 km/h
# New position: 765.0 m
# Speed: 58.4 km/h
# New position: 780.0 m
# Speed: 45.8 km/h
# New position: 780.0 m
# Speed: 48.599999999999994 km/h
# New position: 765.0 m
# Speed: 53.5 km/h
# New position: 780.0 m
# Speed: 50.699999999999996 km/h
# New position: 795.0 m
# Speed: 57.0 km/h
# New position: 780.0 m
# Speed: 40.9 km/h
# New position: 780.0 m
# Speed: 47.9 km/h
# New position: 780.0 m
# Speed: 63.3 km/h
# New position: 765.0 m
# Speed: 52.8 km/h
# New position: 765.0 m
# Speed: 52.099999999999994 km/h
# New position: 780.0 m
# Speed: 56.3 km/h
# New position: 795.0 m
# Speed: 46.5 km/h
# New position: 795.0 m
# Speed: 33.9 km/h
# New position: 780.0 m
# Speed: 45.8 km/h
# New position: 780.0 m
# Speed: 42.3 km/h
# New position: 795.0 m
# Speed: 51.4 km/h
# New position: 810.0 m

# %% [markdown]
# $\textbf{Comparing then elapsed time as d\_discr varies}$

# %%
dict = {}

for i in range(100, 900, 100):
    v_discr = i
    d_discr = i   
    f = GaussianPlant(d_max, d_min, v_max, v_min, d_discr, v_discr, a_c, b_c, sigma_c, "analytic")
    g = GaussianPlant(d_max, d_min, v_max, v_min, d_discr, v_discr, a_e, b_e, sigma_e, "analytic")
    target_policy = TargetPolicy(g, fmean, fstd)

    solver = AnalyticalSolver(f, g, target_policy)
    t = time.time()
    solver.closedLoop()
    elapsed = time.time() - t
    del f
    del g
    del target_policy
    dict[i] = elapsed
# Out:
# Speed: 65.4 km/h
# New position: 23.83791459111608 m
# Speed: 54.199999999999996 km/h
# New position: 31.110389225428925 m
# Speed: 52.099999999999994 km/h
# New position: 33.938559385265435 m
# Speed: 54.199999999999996 km/h
# New position: 60.262463341579576 m
# Speed: 62.599999999999994 km/h
# New position: 65.91441299014654 m
# Speed: 60.5 km/h
# New position: 71.09326094480332 m
# Speed: 57.0 km/h
# New position: 106.23992551974774 m
# Speed: 45.8 km/h
# New position: 129.44904496936414 m
# Speed: 66.8 km/h
# New position: 171.02422603607616 m
# Speed: 59.099999999999994 km/h
# New position: 170.62741593814104 m
# Speed: 65.4 km/h
# New position: 169.32597525607036 m
# Speed: 50.0 km/h
# New position: 159.74897293137127 m
# Speed: 64.0 km/h
# New position: 190.267478932567 m
# Speed: 66.8 km/h
# New position: 234.09626987864422 m
# Speed: 41.599999999999994 km/h
# New position: 255.65611584934925 m
# Speed: 55.599999999999994 km/h
# New position: 271.5742172056843 m
# Speed: 46.5 km/h
# New position: 265.32466895844834 m
# Speed: 54.199999999999996 km/h
# New position: 293.71244319002835 m
# Speed: 55.599999999999994 km/h
# New position: 326.02739824936634 m
# Speed: 60.5 km/h
# New position: 342.06136908988395 m
# Speed: 57.0 km/h
# New position: 345.89795091518744 m
# Speed: 47.199999999999996 km/h
# New position: 366.03131998108023 m
# Speed: 56.3 km/h
# New position: 371.52572734046436 m
# Speed: 55.599999999999994 km/h
# New position: 386.52151235595403 m
# Speed: 57.0 km/h
# New position: 389.67831324591117 m
# Speed: 53.5 km/h
# New position: 412.70165662910154 m
# Speed: 53.5 km/h
# New position: 424.75252010097404 m
# Speed: 54.9 km/h
# New position: 444.1797558203157 m
# Speed: 49.3 km/h
# New position: 455.14764817388385 m
# Speed: 59.099999999999994 km/h
# New position: 429.6265834774457 m
# Speed: 45.8 km/h
# New position: 441.3817122838709 m
# Speed: 65.4 km/h
# New position: 462.00645359924954 m
# Speed: 57.0 km/h
# New position: 500.0507061597225 m
# Speed: 47.9 km/h
# New position: 501.9793526110824 m
# Speed: 53.5 km/h
# New position: 531.794556511604 m
# Speed: 66.1 km/h
# New position: 536.1988535786693 m
# Speed: 52.099999999999994 km/h
# New position: 561.7654771977889 m
# Speed: 50.699999999999996 km/h
# New position: 575.614823457805 m
# Speed: 52.099999999999994 km/h
# New position: 578.885568102121 m
# Speed: 45.099999999999994 km/h
# New position: 567.1520422348522 m
# Speed: 52.099999999999994 km/h
# New position: 582.4825054433605 m
# Speed: 54.9 km/h
# New position: 594.3627244929041 m
# Speed: 53.5 km/h
# New position: 618.3327057417823 m
# Speed: 52.8 km/h
# New position: 644.7464275859695 m
# Speed: 57.0 km/h
# New position: 662.9170782180613 m
# Speed: 46.5 km/h
# New position: 666.8488139481864 m
# Speed: 54.9 km/h
# New position: 662.0586763874416 m
# Speed: 54.9 km/h
# New position: 667.0514405000669 m
# Speed: 43.7 km/h
# New position: 657.5238382234446 m
# Speed: 60.5 km/h
# New position: 660.542421129143 m
# Speed: 57.0 km/h
# New position: 667.9178105009614 m
# Speed: 50.699999999999996 km/h
# New position: 682.3369143845487 m
# Speed: 47.199999999999996 km/h
# New position: 664.9929978420912 m
# Speed: 50.699999999999996 km/h
# New position: 676.5461958827249 m
# Speed: 50.0 km/h
# New position: 681.3263582527045 m
# Speed: 52.099999999999994 km/h
# New position: 668.0547248348705 m
# Speed: 43.7 km/h
# New position: 708.507193871531 m
# Speed: 40.9 km/h
# New position: 703.3920128453503 m
# Speed: 45.8 km/h
# New position: 704.7662719286509 m
# Speed: 45.8 km/h
# New position: 694.0374550801581 m
# Speed: 50.0 km/h
# New position: 707.7332240821745 m
# Speed: 62.599999999999994 km/h
# New position: 726.0210306911354 m
# Speed: 40.9 km/h
# New position: 731.1658891642134 m
# Speed: 45.099999999999994 km/h
# New position: 726.9179609884791 m
# Speed: 51.4 km/h
# New position: 720.9399887658806 m
# Speed: 40.9 km/h
# New position: 739.3361411248543 m
# Speed: 59.099999999999994 km/h
# New position: 742.2079626887358 m
# Speed: 49.3 km/h
# New position: 747.4385303967744 m
# Speed: 44.4 km/h
# New position: 750.0018153648306 m
# Speed: 38.8 km/h
# New position: 755.8404323993489 m
# Speed: 53.5 km/h
# New position: 768.289304420955 m
# Speed: 50.0 km/h
# New position: 772.7007125693613 m
# Speed: 40.9 km/h
# New position: 779.6107873950942 m
# Speed: 47.9 km/h
# New position: 795.1346345965827 m
# Speed: 50.699999999999996 km/h
# New position: 790.8209664200273 m
# Speed: 63.3 km/h
# New position: 798.4996961005186 m
# Speed: 47.9 km/h
# New position: 809.07001635871 m
# Speed: 65.75 km/h
# New position: 19.415846079192562 m
# Speed: 48.25 km/h
# New position: 37.4675435787217 m
# Speed: 59.099999999999994 km/h
# New position: 51.19721376726723 m
# Speed: 54.9 km/h
# New position: 71.34425349245032 m
# Speed: 54.199999999999996 km/h
# New position: 88.28195082998262 m
# Speed: 56.65 km/h
# New position: 118.8166006317978 m
# Speed: 52.099999999999994 km/h
# New position: 121.73475884134112 m
# Speed: 58.05 km/h
# New position: 138.5873638529112 m
# Speed: 44.05 km/h
# New position: 169.13652351938063 m
# Speed: 48.949999999999996 km/h
# New position: 192.64528411812614 m
# Speed: 57.349999999999994 km/h
# New position: 204.41840150635954 m
# Speed: 69.6 km/h
# New position: 221.96419260468565 m
# Speed: 59.449999999999996 km/h
# New position: 235.1090482773781 m
# Speed: 54.55 km/h
# New position: 228.02614853722142 m
# Speed: 57.699999999999996 km/h
# New position: 227.21589351889415 m
# Speed: 64.35 km/h
# New position: 270.52202576659107 m
# Speed: 63.3 km/h
# New position: 282.51301398653317 m
# Speed: 60.849999999999994 km/h
# New position: 281.2691389819862 m
# Speed: 53.849999999999994 km/h
# New position: 290.4315651098737 m
# Speed: 54.9 km/h
# New position: 310.3588825863924 m
# Speed: 58.05 km/h
# New position: 285.8439028541914 m
# Speed: 58.05 km/h
# New position: 292.11919900621837 m
# Speed: 47.55 km/h
# New position: 318.53318394838755 m
# Speed: 57.349999999999994 km/h
# New position: 323.9556087399193 m
# Speed: 65.4 km/h
# New position: 324.83559658398633 m
# Speed: 70.3 km/h
# New position: 344.07972814724786 m
# Speed: 61.9 km/h
# New position: 365.59327380556687 m
# Speed: 46.15 km/h
# New position: 373.13611199289363 m
# Speed: 53.15 km/h
# New position: 394.4678435238117 m
# Speed: 55.949999999999996 km/h
# New position: 408.46474675506755 m
# Speed: 58.75 km/h
# New position: 429.3207137054485 m
# Speed: 51.05 km/h
# New position: 435.0392066501654 m
# Speed: 51.05 km/h
# New position: 422.7622934953388 m
# Speed: 59.099999999999994 km/h
# New position: 441.6960573690009 m
# Speed: 60.15 km/h
# New position: 449.2501352428788 m
# Speed: 50.0 km/h
# New position: 481.25685759547935 m
# Speed: 54.55 km/h
# New position: 501.1512258051836 m
# Speed: 52.8 km/h
# New position: 513.1320592276436 m
# Speed: 56.65 km/h
# New position: 530.9080312658302 m
# Speed: 48.949999999999996 km/h
# New position: 570.27565947979 m
# Speed: 54.9 km/h
# New position: 566.713808734946 m
# Speed: 44.75 km/h
# New position: 579.5118182322362 m
# Speed: 47.55 km/h
# New position: 557.2168989982997 m
# Speed: 52.449999999999996 km/h
# New position: 572.4417070753296 m
# Speed: 54.55 km/h
# New position: 561.0299303981832 m
# Speed: 58.4 km/h
# New position: 559.6719428710097 m
# Speed: 55.599999999999994 km/h
# New position: 575.7748306437933 m
# Speed: 48.949999999999996 km/h
# New position: 573.9083569692033 m
# Speed: 47.199999999999996 km/h
# New position: 599.0619116482584 m
# Speed: 50.0 km/h
# New position: 603.9076250738699 m
# Speed: 68.55 km/h
# New position: 604.1749000233975 m
# Speed: 48.25 km/h
# New position: 597.4858562935643 m
# Speed: 54.55 km/h
# New position: 595.2707236210447 m
# Speed: 51.05 km/h
# New position: 615.8669609243559 m
# Speed: 59.8 km/h
# New position: 619.1414366688101 m
# Speed: 43.7 km/h
# New position: 650.173106421292 m
# Speed: 41.95 km/h
# New position: 669.2276375000347 m
# Speed: 48.949999999999996 km/h
# New position: 689.0217637017957 m
# Speed: 37.4 km/h
# New position: 677.2919596269094 m
# Speed: 52.8 km/h
# New position: 680.8276081199742 m
# Speed: 51.05 km/h
# New position: 675.5248696936484 m
# Speed: 61.199999999999996 km/h
# New position: 669.8051526486869 m
# Speed: 44.75 km/h
# New position: 674.1336525354538 m
# Speed: 50.699999999999996 km/h
# New position: 663.7882034795729 m
# Speed: 59.8 km/h
# New position: 672.0436068442905 m
# Speed: 51.75 km/h
# New position: 684.8363450002025 m
# Speed: 44.05 km/h
# New position: 666.0111608879082 m
# Speed: 55.949999999999996 km/h
# New position: 687.3109416855185 m
# Speed: 43.7 km/h
# New position: 683.3179294291176 m
# Speed: 58.75 km/h
# New position: 692.4788423148418 m
# Speed: 51.05 km/h
# New position: 691.2867228932554 m
# Speed: 44.05 km/h
# New position: 725.7055982349436 m
# Speed: 45.45 km/h
# New position: 721.8153198904197 m
# Speed: 51.05 km/h
# New position: 730.603501336152 m
# Speed: 48.949999999999996 km/h
# New position: 740.2952609396409 m
# Speed: 44.4 km/h
# New position: 760.5080593363589 m
# Speed: 41.95 km/h
# New position: 767.3817976428562 m
# Speed: 63.3 km/h
# New position: 800.9223007254797 m
# Speed: 59.8 km/h
# New position: 49.76854313115719 m
# Speed: 64.23333333333333 km/h
# New position: 72.3963860274286 m
# Speed: 58.86666666666667 km/h
# New position: 81.50558688563132 m
# Speed: 64.93333333333334 km/h
# New position: 120.25436004454144 m
# Speed: 65.63333333333333 km/h
# New position: 173.032519492305 m
# Speed: 53.96666666666667 km/h
# New position: 180.35562202371457 m
# Speed: 58.86666666666667 km/h
# New position: 192.572420169874 m
# Speed: 61.2 km/h
# New position: 214.72452995242267 m
# Speed: 51.86666666666667 km/h
# New position: 219.4131940135823 m
# Speed: 53.96666666666667 km/h
# New position: 218.3923871402906 m
# Speed: 65.63333333333333 km/h
# New position: 242.32784347989983 m
# Speed: 64.93333333333334 km/h
# New position: 264.876315538163 m
# Speed: 65.4 km/h
# New position: 294.4857067848149 m
# Speed: 57.93333333333334 km/h
# New position: 302.49280154509404 m
# Speed: 54.666666666666664 km/h
# New position: 302.1126908178922 m
# Speed: 59.333333333333336 km/h
# New position: 311.8030055524679 m
# Speed: 47.9 km/h
# New position: 299.8411355875282 m
# Speed: 60.266666666666666 km/h
# New position: 316.89298999109263 m
# Speed: 59.8 km/h
# New position: 339.5561304003843 m
# Speed: 57.7 km/h
# New position: 344.5210230906107 m
# Speed: 53.96666666666667 km/h
# New position: 368.656594379072 m
# Speed: 45.33333333333333 km/h
# New position: 354.30618984015666 m
# Speed: 52.56666666666667 km/h
# New position: 338.70415241132946 m
# Speed: 51.166666666666664 km/h
# New position: 329.0631508409786 m
# Speed: 50.7 km/h
# New position: 353.6615549399383 m
# Speed: 48.13333333333333 km/h
# New position: 367.6765873243493 m
# Speed: 54.2 km/h
# New position: 389.90893430234615 m
# Speed: 54.43333333333334 km/h
# New position: 418.96232578699596 m
# Speed: 61.666666666666664 km/h
# New position: 422.8973573207056 m
# Speed: 60.96666666666667 km/h
# New position: 436.8955523533888 m
# Speed: 64.7 km/h
# New position: 427.7418804542002 m
# Speed: 51.86666666666667 km/h
# New position: 432.6304533488009 m
# Speed: 50.46666666666667 km/h
# New position: 440.5100161761686 m
# Speed: 52.1 km/h
# New position: 477.8804468428009 m
# Speed: 52.1 km/h
# New position: 483.44815809067734 m
# Speed: 47.2 km/h
# New position: 488.02642212671356 m
# Speed: 52.56666666666667 km/h
# New position: 492.3960835333892 m
# Speed: 50.233333333333334 km/h
# New position: 490.4872416052595 m
# Speed: 60.266666666666666 km/h
# New position: 477.54051720411167 m
# Speed: 44.16666666666667 km/h
# New position: 477.35642099664244 m
# Speed: 56.53333333333333 km/h
# New position: 497.9638372796992 m
# Speed: 50.93333333333334 km/h
# New position: 507.4042441443007 m
# Speed: 51.63333333333333 km/h
# New position: 499.06294468144495 m
# Speed: 55.833333333333336 km/h
# New position: 531.7986527978483 m
# Speed: 50.233333333333334 km/h
# New position: 531.390036851841 m
# Speed: 57.93333333333334 km/h
# New position: 535.9003197276047 m
# Speed: 60.5 km/h
# New position: 545.3551109870788 m
# Speed: 62.6 km/h
# New position: 555.5755407843966 m
# Speed: 55.13333333333333 km/h
# New position: 541.0336520180657 m
# Speed: 58.166666666666664 km/h
# New position: 561.0934732542748 m
# Speed: 43.0 km/h
# New position: 563.6265632311868 m
# Speed: 49.06666666666667 km/h
# New position: 561.0580116139247 m
# Speed: 56.06666666666667 km/h
# New position: 552.5066490748559 m
# Speed: 49.53333333333333 km/h
# New position: 546.466387910568 m
# Speed: 57.233333333333334 km/h
# New position: 522.4166271931791 m
# Speed: 56.766666666666666 km/h
# New position: 542.6490997814598 m
# Speed: 54.666666666666664 km/h
# New position: 574.8538087773181 m
# Speed: 56.53333333333333 km/h
# New position: 568.4898669845388 m
# Speed: 49.06666666666667 km/h
# New position: 572.1401482641164 m
# Speed: 59.1 km/h
# New position: 579.47645853272 m
# Speed: 56.53333333333333 km/h
# New position: 583.1766614182955 m
# Speed: 58.86666666666667 km/h
# New position: 581.6872993303871 m
# Speed: 59.8 km/h
# New position: 584.6792793236065 m
# Speed: 54.9 km/h
# New position: 617.6533934271268 m
# Speed: 51.4 km/h
# New position: 637.5888910674557 m
# Speed: 51.86666666666667 km/h
# New position: 630.6380423982001 m
# Speed: 56.53333333333333 km/h
# New position: 635.3382876355826 m
# Speed: 48.833333333333336 km/h
# New position: 632.8346317586628 m
# Speed: 52.1 km/h
# New position: 623.102300655324 m
# Speed: 55.6 km/h
# New position: 643.2258199297041 m
# Speed: 49.766666666666666 km/h
# New position: 668.8059600458953 m
# Speed: 46.266666666666666 km/h
# New position: 687.2607767253543 m
# Speed: 54.666666666666664 km/h
# New position: 674.948452958158 m
# Speed: 43.233333333333334 km/h
# New position: 692.2344923790778 m
# Speed: 53.96666666666667 km/h
# New position: 705.8342186418564 m
# Speed: 59.8 km/h
# New position: 712.0764964079083 m
# Speed: 55.833333333333336 km/h
# New position: 715.5881446307773 m
# Speed: 64.0 km/h
# New position: 732.6291806947559 m
# Speed: 46.733333333333334 km/h
# New position: 742.0069568684935 m
# Speed: 56.53333333333333 km/h
# New position: 762.6472447220685 m
# Speed: 46.03333333333333 km/h
# New position: 760.1625711660977 m
# Speed: 56.06666666666667 km/h
# New position: 770.5362794207813 m
# Speed: 46.5 km/h
# New position: 755.5999023610527 m
# Speed: 38.1 km/h
# New position: 749.2583129304389 m
# Speed: 39.733333333333334 km/h
# New position: 749.7376742507174 m
# Speed: 41.83333333333333 km/h
# New position: 729.8354104636277 m
# Speed: 44.16666666666667 km/h
# New position: 723.8652822268575 m
# Speed: 52.56666666666667 km/h
# New position: 689.5424577088313 m
# Speed: 60.96666666666667 km/h
# New position: 682.1664186427691 m
# Speed: 55.36666666666667 km/h
# New position: 683.6561189548236 m
# Speed: 47.43333333333334 km/h
# New position: 682.5869827599197 m
# Speed: 60.733333333333334 km/h
# New position: 679.6058908533165 m
# Speed: 38.33333333333333 km/h
# New position: 680.7761452201551 m
# Speed: 55.36666666666667 km/h
# New position: 673.0726772423084 m
# Speed: 44.86666666666667 km/h
# New position: 672.5937277255641 m
# Speed: 49.766666666666666 km/h
# New position: 673.8239714628749 m
# Speed: 43.93333333333334 km/h
# New position: 667.5549805572022 m
# Speed: 57.233333333333334 km/h
# New position: 685.1709514076407 m
# Speed: 61.666666666666664 km/h
# New position: 703.1024584878654 m
# Speed: 53.03333333333333 km/h
# New position: 716.4354153687422 m
# Speed: 42.3 km/h
# New position: 724.6013924522423 m
# Speed: 46.5 km/h
# New position: 712.851074079933 m
# Speed: 50.233333333333334 km/h
# New position: 710.5823897787567 m
# Speed: 56.3 km/h
# New position: 716.8160982507408 m
# Speed: 51.4 km/h
# New position: 728.7458536026603 m
# Speed: 54.9 km/h
# New position: 756.5862278158177 m
# Speed: 53.5 km/h
# New position: 764.3854860010615 m
# Speed: 47.9 km/h
# New position: 758.1068039942635 m
# Speed: 39.5 km/h
# New position: 749.8874085477545 m
# Speed: 59.1 km/h
# New position: 750.4326921278513 m
# Speed: 41.83333333333333 km/h
# New position: 775.636165457037 m
# Speed: 46.5 km/h
# New position: 775.2929048005864 m
# Speed: 49.06666666666667 km/h
# New position: 780.3630029134737 m
# Speed: 44.400000000000006 km/h
# New position: 766.4657480869995 m
# Speed: 60.03333333333333 km/h
# New position: 783.7623092517324 m
# Speed: 55.13333333333333 km/h
# New position: 801.2968115434103 m
# Speed: 57.875 km/h
# New position: 29.35130449133395 m
# Speed: 59.625 km/h
# New position: 79.02082941478835 m
# Speed: 48.074999999999996 km/h
# New position: 86.7706708116593 m
# Speed: 56.125 km/h
# New position: 98.36322624389626 m
# Speed: 52.974999999999994 km/h
# New position: 125.68621015804857 m
# Speed: 61.55 km/h
# New position: 149.40753006037437 m
# Speed: 66.8 km/h
# New position: 193.4768013457151 m
# Speed: 49.824999999999996 km/h
# New position: 207.33040726111224 m
# Speed: 43.0 km/h
# New position: 216.1835216991333 m
# Speed: 46.15 km/h
# New position: 221.67372629595314 m
# Speed: 63.824999999999996 km/h
# New position: 237.77232975003713 m
# Speed: 57.175 km/h
# New position: 246.4883119576537 m
# Speed: 53.5 km/h
# New position: 260.85197644772717 m
# Speed: 69.775 km/h
# New position: 270.9272123046833 m
# Speed: 59.974999999999994 km/h
# New position: 290.79967885250346 m
# Speed: 52.974999999999994 km/h
# New position: 316.0303338353405 m
# Speed: 52.974999999999994 km/h
# New position: 319.1311805165425 m
# Speed: 52.449999999999996 km/h
# New position: 341.00000168286186 m
# Speed: 43.525 km/h
# New position: 350.9258022970272 m
# Speed: 61.375 km/h
# New position: 367.8837470326908 m
# Speed: 56.65 km/h
# New position: 394.9111963665193 m
# Speed: 49.474999999999994 km/h
# New position: 407.66693260263605 m
# Speed: 51.925 km/h
# New position: 432.1403339849095 m
# Speed: 51.05 km/h
# New position: 428.2463964221739 m
# Speed: 46.5 km/h
# New position: 415.85182963685617 m
# Speed: 50.699999999999996 km/h
# New position: 441.0915534180091 m
# Speed: 56.824999999999996 km/h
# New position: 464.2521957638328 m
# Speed: 53.324999999999996 km/h
# New position: 475.52726914447203 m
# Speed: 47.199999999999996 km/h
# New position: 482.09440520263496 m
# Speed: 48.775 km/h
# New position: 483.2503271974034 m
# Speed: 60.5 km/h
# New position: 487.59191983634895 m
# Speed: 56.824999999999996 km/h
# New position: 494.13847925827173 m
# Speed: 64.0 km/h
# New position: 502.08554527259656 m
# Speed: 45.275 km/h
# New position: 499.18775637539954 m
# Speed: 59.275 km/h
# New position: 483.7379358972122 m
# Speed: 51.75 km/h
# New position: 504.0288951062737 m
# Speed: 59.974999999999994 km/h
# New position: 526.7546174207463 m
# Speed: 60.15 km/h
# New position: 542.3304207125317 m
# Speed: 51.75 km/h
# New position: 526.120107768783 m
# Speed: 51.75 km/h
# New position: 524.5397888507777 m
# Speed: 51.4 km/h
# New position: 544.0406601102884 m
# Speed: 59.625 km/h
# New position: 545.0414038906362 m
# Speed: 55.775 km/h
# New position: 528.8826883883385 m
# Speed: 54.025 km/h
# New position: 545.8372467725983 m
# Speed: 57.525 km/h
# New position: 545.7618605496776 m
# Speed: 59.099999999999994 km/h
# New position: 548.353604239841 m
# Speed: 54.199999999999996 km/h
# New position: 569.8494164440311 m
# Speed: 48.074999999999996 km/h
# New position: 558.4527721742808 m
# Speed: 59.625 km/h
# New position: 574.9672363975196 m
# Speed: 62.599999999999994 km/h
# New position: 570.0739351218248 m
# Speed: 52.974999999999994 km/h
# New position: 585.5796549834023 m
# Speed: 66.975 km/h
# New position: 570.9317517499413 m
# Speed: 64.35 km/h
# New position: 590.5043939495881 m
# Speed: 50.349999999999994 km/h
# New position: 592.5972704672714 m
# Speed: 55.949999999999996 km/h
# New position: 588.7316927833301 m
# Speed: 54.199999999999996 km/h
# New position: 585.8590024840368 m
# Speed: 51.75 km/h
# New position: 592.7037641130678 m
# Speed: 47.025 km/h
# New position: 590.8127953947403 m
# Speed: 47.9 km/h
# New position: 579.654672428814 m
# Speed: 52.275 km/h
# New position: 589.4120727095197 m
# Speed: 53.675 km/h
# New position: 589.1620867424122 m
# Speed: 50.349999999999994 km/h
# New position: 598.36322515704 m
# Speed: 61.199999999999996 km/h
# New position: 608.50890309219 m
# Speed: 64.525 km/h
# New position: 631.4451951705081 m
# Speed: 49.474999999999994 km/h
# New position: 624.4567157271006 m
# Speed: 51.574999999999996 km/h
# New position: 650.2861484130585 m
# Speed: 56.125 km/h
# New position: 666.1829331204144 m
# Speed: 55.425 km/h
# New position: 663.6645671309876 m
# Speed: 58.05 km/h
# New position: 675.0257755599068 m
# Speed: 40.025 km/h
# New position: 675.5212427185984 m
# Speed: 67.85 km/h
# New position: 684.0009942776682 m
# Speed: 55.949999999999996 km/h
# New position: 678.895717680739 m
# Speed: 52.449999999999996 km/h
# New position: 686.4396213989662 m
# Speed: 43.0 km/h
# New position: 693.5498921633932 m
# Speed: 54.199999999999996 km/h
# New position: 666.7394784907491 m
# Speed: 51.05 km/h
# New position: 658.1213256613655 m
# Speed: 53.324999999999996 km/h
# New position: 675.5605087845722 m
# Speed: 56.474999999999994 km/h
# New position: 694.0573510143595 m
# Speed: 56.125 km/h
# New position: 690.4491284484823 m
# Speed: 44.925 km/h
# New position: 701.4967809069386 m
# Speed: 46.5 km/h
# New position: 708.5570298135983 m
# Speed: 51.925 km/h
# New position: 714.0487265894068 m
# Speed: 49.3 km/h
# New position: 714.5112949928272 m
# Speed: 51.224999999999994 km/h
# New position: 733.0811967330603 m
# Speed: 47.375 km/h
# New position: 721.2096855470814 m
# Speed: 43.7 km/h
# New position: 714.5985042356846 m
# Speed: 46.849999999999994 km/h
# New position: 724.507291814215 m
# Speed: 56.125 km/h
# New position: 722.9624922554732 m
# Speed: 50.349999999999994 km/h
# New position: 737.8181690643356 m
# Speed: 43.525 km/h
# New position: 740.0993780339572 m
# Speed: 41.775 km/h
# New position: 746.9778190863957 m
# Speed: 48.775 km/h
# New position: 739.9120536432076 m
# Speed: 44.75 km/h
# New position: 738.4532471976695 m
# Speed: 56.125 km/h
# New position: 726.3879290099658 m
# Speed: 50.699999999999996 km/h
# New position: 710.6715989873879 m
# Speed: 65.57499999999999 km/h
# New position: 742.47785587164 m
# Speed: 67.15 km/h
# New position: 760.2388332214159 m
# Speed: 48.775 km/h
# New position: 751.9428757538959 m
# Speed: 51.925 km/h
# New position: 761.7472777215223 m
# Speed: 42.825 km/h
# New position: 770.4451256623109 m
# Speed: 53.849999999999994 km/h
# New position: 772.4869878596819 m
# Speed: 43.349999999999994 km/h
# New position: 774.0618215834243 m
# Speed: 54.9 km/h
# New position: 755.5777664684274 m
# Speed: 46.15 km/h
# New position: 764.9055912672026 m
# Speed: 45.099999999999994 km/h
# New position: 776.4476831629709 m
# Speed: 47.9 km/h
# New position: 776.8982811071207 m
# Speed: 40.9 km/h
# New position: 814.6510502499198 m
# Speed: 59.52 km/h
# New position: 17.800796956083442 m
# Speed: 62.040000000000006 km/h
# New position: 54.68602220174016 m
# Speed: 63.300000000000004 km/h
# New position: 84.81809031618916 m
# Speed: 47.34 km/h
# New position: 92.2636230134141 m
# Speed: 63.300000000000004 km/h
# New position: 112.30901024487675 m
# Speed: 66.24000000000001 km/h
# New position: 116.77641075149214 m
# Speed: 63.300000000000004 km/h
# New position: 149.17110657018182 m
# Speed: 68.34 km/h
# New position: 154.28400102882264 m
# Speed: 44.120000000000005 km/h
# New position: 157.6712633584283 m
# Speed: 58.68000000000001 km/h
# New position: 168.10050779744455 m
# Speed: 67.36000000000001 km/h
# New position: 181.60567808937375 m
# Speed: 60.50000000000001 km/h
# New position: 199.5282317857768 m
# Speed: 50.28 km/h
# New position: 233.910048511452 m
# Speed: 46.64 km/h
# New position: 236.70030192733697 m
# Speed: 61.06 km/h
# New position: 244.07943707581654 m
# Speed: 57.980000000000004 km/h
# New position: 253.4575544333623 m
# Speed: 63.160000000000004 km/h
# New position: 258.8665915881119 m
# Speed: 59.24 km/h
# New position: 244.67624672569335 m
# Speed: 59.1 km/h
# New position: 262.6327311985111 m
# Speed: 48.74 km/h
# New position: 280.5911168957325 m
# Speed: 58.260000000000005 km/h
# New position: 301.3865341419409 m
# Speed: 67.36000000000001 km/h
# New position: 302.3199017821712 m
# Speed: 46.36 km/h
# New position: 305.5876194602041 m
# Speed: 54.06 km/h
# New position: 331.00066688957435 m
# Speed: 50.7 km/h
# New position: 356.7719332060476 m
# Speed: 52.38 km/h
# New position: 338.38459022296547 m
# Speed: 50.7 km/h
# New position: 345.000170836883 m
# Speed: 59.24 km/h
# New position: 351.6342466119696 m
# Speed: 41.18000000000001 km/h
# New position: 352.31726287579687 m
# Speed: 59.660000000000004 km/h
# New position: 368.43085007838505 m
# Speed: 61.480000000000004 km/h
# New position: 390.445799251495 m
# Speed: 49.86000000000001 km/h
# New position: 396.08607555580676 m
# Speed: 59.38 km/h
# New position: 405.13014512013257 m
# Speed: 67.92 km/h
# New position: 416.8143883784637 m
# Speed: 60.36000000000001 km/h
# New position: 420.38194390876413 m
# Speed: 51.96 km/h
# New position: 409.70714707350515 m
# Speed: 60.080000000000005 km/h
# New position: 432.6400982796223 m
# Speed: 60.080000000000005 km/h
# New position: 423.4726987246781 m
# Speed: 48.88 km/h
# New position: 434.34352381331496 m
# Speed: 55.32000000000001 km/h
# New position: 441.3479517285406 m
# Speed: 49.02 km/h
# New position: 450.06861978174305 m
# Speed: 50.56 km/h
# New position: 457.7664743602292 m
# Speed: 57.7 km/h
# New position: 440.7346334281944 m
# Speed: 54.34 km/h
# New position: 439.112355710271 m
# Speed: 56.02 km/h
# New position: 445.24774603857685 m
# Speed: 58.68000000000001 km/h
# New position: 438.10157420438173 m
# Speed: 52.52 km/h
# New position: 441.07528877639425 m
# Speed: 59.38 km/h
# New position: 456.48405109995707 m
# Speed: 53.50000000000001 km/h
# New position: 446.9796194004298 m
# Speed: 61.2 km/h
# New position: 448.0669129687242 m
# Speed: 55.46 km/h
# New position: 463.5326519120053 m
# Speed: 61.34 km/h
# New position: 478.8747358948755 m
# Speed: 55.18000000000001 km/h
# New position: 467.26280459268025 m
# Speed: 48.46 km/h
# New position: 453.69187852613476 m
# Speed: 52.800000000000004 km/h
# New position: 451.0824283203894 m
# Speed: 56.02 km/h
# New position: 470.0435420103926 m
# Speed: 51.540000000000006 km/h
# New position: 471.57955345399637 m
# Speed: 57.84 km/h
# New position: 476.90038533336065 m
# Speed: 72.4 km/h
# New position: 494.7263173134156 m
# Speed: 57.84 km/h
# New position: 492.75140045933006 m
# Speed: 62.32000000000001 km/h
# New position: 496.9011574747562 m
# Speed: 59.800000000000004 km/h
# New position: 488.4227298499574 m
# Speed: 55.88 km/h
# New position: 505.98114596056797 m
# Speed: 60.50000000000001 km/h
# New position: 517.9877051633983 m
# Speed: 46.78 km/h
# New position: 517.9408145012304 m
# Speed: 55.32000000000001 km/h
# New position: 536.3191120389733 m
# Speed: 49.440000000000005 km/h
# New position: 556.0428634488533 m
# Speed: 56.86000000000001 km/h
# New position: 552.5967157867769 m
# Speed: 53.36000000000001 km/h
# New position: 563.8632956438673 m
# Speed: 54.34 km/h
# New position: 546.8282365766775 m
# Speed: 48.46 km/h
# New position: 545.2515932023666 m
# Speed: 42.160000000000004 km/h
# New position: 524.3892097051094 m
# Speed: 55.74 km/h
# New position: 523.6134742185575 m
# Speed: 56.160000000000004 km/h
# New position: 527.332557471281 m
# Speed: 56.580000000000005 km/h
# New position: 514.6703279393753 m
# Speed: 48.32 km/h
# New position: 524.2319128248961 m
# Speed: 50.0 km/h
# New position: 532.8450614489202 m
# Speed: 56.02 km/h
# New position: 536.3871785993204 m
# Speed: 46.22 km/h
# New position: 521.122554358098 m
# Speed: 55.88 km/h
# New position: 521.0301897924977 m
# Speed: 47.900000000000006 km/h
# New position: 544.8838485774736 m
# Speed: 47.900000000000006 km/h
# New position: 537.524535549391 m
# Speed: 50.0 km/h
# New position: 552.6911255848601 m
# Speed: 41.46 km/h
# New position: 537.3059146730106 m
# Speed: 69.46000000000001 km/h
# New position: 537.7402821236734 m
# Speed: 55.040000000000006 km/h
# New position: 536.6076413773583 m
# Speed: 51.96 km/h
# New position: 524.3320437918055 m
# Speed: 59.940000000000005 km/h
# New position: 511.97477772283014 m
# Speed: 49.02 km/h
# New position: 490.0080456245246 m
# Speed: 53.92 km/h
# New position: 488.42661202540114 m
# Speed: 48.040000000000006 km/h
# New position: 496.11664263645247 m
# Speed: 52.52 km/h
# New position: 509.9343807556647 m
# Speed: 53.78 km/h
# New position: 508.79199043163374 m
# Speed: 55.74 km/h
# New position: 531.4755455172747 m
# Speed: 53.50000000000001 km/h
# New position: 548.1542321515096 m
# Speed: 47.620000000000005 km/h
# New position: 530.5954532743086 m
# Speed: 56.300000000000004 km/h
# New position: 557.7473202452152 m
# Speed: 60.36000000000001 km/h
# New position: 563.2246131901343 m
# Speed: 61.900000000000006 km/h
# New position: 572.0265191819897 m
# Speed: 53.92 km/h
# New position: 597.0826800093264 m
# Speed: 46.08 km/h
# New position: 585.1023368896584 m
# Speed: 46.36 km/h
# New position: 583.1067478504694 m
# Speed: 39.92 km/h
# New position: 601.5875694277129 m
# Speed: 59.52 km/h
# New position: 625.0767869606456 m
# Speed: 41.32000000000001 km/h
# New position: 631.7524193818645 m
# Speed: 48.32 km/h
# New position: 643.9240666214529 m
# Speed: 43.28 km/h
# New position: 650.5638532377477 m
# Speed: 34.32 km/h
# New position: 629.1171801537513 m
# Speed: 55.74 km/h
# New position: 635.4631731849527 m
# Speed: 46.92 km/h
# New position: 638.4186205364894 m
# Speed: 55.32000000000001 km/h
# New position: 638.4907336654782 m
# Speed: 37.96 km/h
# New position: 649.7065748164737 m
# Speed: 46.36 km/h
# New position: 637.8298332414605 m
# Speed: 60.50000000000001 km/h
# New position: 652.4968744452427 m
# Speed: 56.300000000000004 km/h
# New position: 655.4087615212325 m
# Speed: 58.540000000000006 km/h
# New position: 669.6225982001608 m
# Speed: 48.74 km/h
# New position: 667.9386533452537 m
# Speed: 51.82 km/h
# New position: 692.1348755460311 m
# Speed: 44.68000000000001 km/h
# New position: 692.7711176394665 m
# Speed: 45.1 km/h
# New position: 701.9513482236223 m
# Speed: 48.32 km/h
# New position: 706.4109567139728 m
# Speed: 39.22 km/h
# New position: 681.9499398118545 m
# Speed: 43.42 km/h
# New position: 671.2668071163612 m
# Speed: 46.92 km/h
# New position: 677.5450553824428 m
# Speed: 49.300000000000004 km/h
# New position: 658.1623937818213 m
# Speed: 64.14000000000001 km/h
# New position: 689.2785061643342 m
# Speed: 45.52 km/h
# New position: 686.288333714916 m
# Speed: 55.6 km/h
# New position: 700.57525584259 m
# Speed: 70.02000000000001 km/h
# New position: 727.8549910821055 m
# Speed: 52.52 km/h
# New position: 750.3673890894754 m
# Speed: 34.46 km/h
# New position: 754.7220204110553 m
# Speed: 41.74 km/h
# New position: 748.553933800749 m
# Speed: 34.88 km/h
# New position: 741.8909315089965 m
# Speed: 50.28 km/h
# New position: 723.724285393342 m
# Speed: 45.52 km/h
# New position: 731.6957623678662 m
# Speed: 37.96 km/h
# New position: 741.0269043828284 m
# Speed: 57.14 km/h
# New position: 727.8119967774818 m
# Speed: 51.82 km/h
# New position: 758.3008084770619 m
# Speed: 59.940000000000005 km/h
# New position: 753.7425616824528 m
# Speed: 46.78 km/h
# New position: 753.9175249381036 m
# Speed: 47.760000000000005 km/h
# New position: 752.2113055412221 m
# Speed: 56.86000000000001 km/h
# New position: 770.6327158933672 m
# Speed: 44.540000000000006 km/h
# New position: 779.4791285480031 m
# Speed: 53.36000000000001 km/h
# New position: 764.7197122506184 m
# Speed: 43.56 km/h
# New position: 752.4746809538498 m
# Speed: 45.52 km/h
# New position: 749.2033103770526 m
# Speed: 54.900000000000006 km/h
# New position: 759.7747557184617 m
# Speed: 45.660000000000004 km/h
# New position: 741.6538023031825 m
# Speed: 46.08 km/h
# New position: 738.3278557271775 m
# Speed: 48.18 km/h
# New position: 735.833228987318 m
# Speed: 47.06 km/h
# New position: 735.5273416430792 m
# Speed: 47.06 km/h
# New position: 725.1136105661753 m
# Speed: 54.900000000000006 km/h
# New position: 714.6222345236175 m
# Speed: 47.900000000000006 km/h
# New position: 715.8414853052639 m
# Speed: 49.02 km/h
# New position: 718.2743809660965 m
# Speed: 60.64000000000001 km/h
# New position: 712.9080462099349 m
# Speed: 47.620000000000005 km/h
# New position: 730.4019040522222 m
# Speed: 49.160000000000004 km/h
# New position: 745.7562146353478 m
# Speed: 53.64 km/h
# New position: 748.962810057608 m
# Speed: 50.28 km/h
# New position: 758.6276440212156 m
# Speed: 55.74 km/h
# New position: 760.1233513966412 m
# Speed: 45.1 km/h
# New position: 750.6867702730881 m
# Speed: 48.46 km/h
# New position: 757.5935669220156 m
# Speed: 51.400000000000006 km/h
# New position: 769.3821508941719 m
# Speed: 45.52 km/h
# New position: 776.1976484094572 m
# Speed: 57.84 km/h
# New position: 781.7073140636041 m
# Speed: 61.34 km/h
# New position: 784.8917331507787 m
# Speed: 54.760000000000005 km/h
# New position: 801.5281356287878 m
# Speed: 48.36666666666667 km/h
# New position: 21.547561771439188 m
# Speed: 47.43333333333334 km/h
# New position: 19.563831244464357 m
# Speed: 60.266666666666666 km/h
# New position: 40.35681820531678 m
# Speed: 54.31666666666667 km/h
# New position: 72.02661796830151 m
# Speed: 59.56666666666667 km/h
# New position: 103.15954424876006 m
# Speed: 44.983333333333334 km/h
# New position: 126.5577259476002 m
# Speed: 54.31666666666667 km/h
# New position: 142.56526182162057 m
# Speed: 58.4 km/h
# New position: 148.01543453453033 m
# Speed: 47.43333333333334 km/h
# New position: 162.29871875756598 m
# Speed: 53.15 km/h
# New position: 156.37384226361846 m
# Speed: 64.23333333333333 km/h
# New position: 177.86979304553145 m
# Speed: 58.983333333333334 km/h
# New position: 196.0720558303234 m
# Speed: 62.833333333333336 km/h
# New position: 205.2355787435723 m
# Speed: 61.550000000000004 km/h
# New position: 216.3899785120325 m
# Speed: 56.416666666666664 km/h
# New position: 221.24386163558094 m
# Speed: 67.38333333333333 km/h
# New position: 234.41501860771982 m
# Speed: 51.86666666666667 km/h
# New position: 255.8636039923099 m
# Speed: 50.11666666666667 km/h
# New position: 276.3951152553084 m
# Speed: 55.25 km/h
# New position: 273.1578387464734 m
# Speed: 70.30000000000001 km/h
# New position: 290.39580541039123 m
# Speed: 53.266666666666666 km/h
# New position: 291.5504106033883 m
# Speed: 63.53333333333333 km/h
# New position: 290.50012185365125 m
# Speed: 46.733333333333334 km/h
# New position: 313.2901432033903 m
# Speed: 64.0 km/h
# New position: 323.1663434991145 m
# Speed: 51.05 km/h
# New position: 351.9247525209599 m
# Speed: 52.916666666666664 km/h
# New position: 378.2232172025433 m
# Speed: 69.01666666666667 km/h
# New position: 395.10419650588847 m
# Speed: 46.61666666666667 km/h
# New position: 386.04706517983055 m
# Speed: 47.55 km/h
# New position: 383.72134177769505 m
# Speed: 63.06666666666667 km/h
# New position: 384.4698526941837 m
# Speed: 58.63333333333333 km/h
# New position: 399.7853903160985 m
# Speed: 55.016666666666666 km/h
# New position: 409.2402562424731 m
# Speed: 51.28333333333333 km/h
# New position: 409.8872747773371 m
# Speed: 50.583333333333336 km/h
# New position: 431.49006708164274 m
# Speed: 58.63333333333333 km/h
# New position: 432.9142884100065 m
# Speed: 57.81666666666667 km/h
# New position: 434.01804961433976 m
# Speed: 53.61666666666667 km/h
# New position: 447.73303149638525 m
# Speed: 51.516666666666666 km/h
# New position: 447.8362749154183 m
# Speed: 53.61666666666667 km/h
# New position: 449.98152759748854 m
# Speed: 47.43333333333334 km/h
# New position: 467.831908596041 m
# Speed: 57.35 km/h
# New position: 483.15579534383903 m
# Speed: 63.65 km/h
# New position: 481.4245325034354 m
# Speed: 51.983333333333334 km/h
# New position: 481.41756642229086 m
# Speed: 56.06666666666667 km/h
# New position: 477.8452261020328 m
# Speed: 42.53333333333333 km/h
# New position: 480.64794620796414 m
# Speed: 57.81666666666667 km/h
# New position: 507.40806814523535 m
# Speed: 46.96666666666667 km/h
# New position: 493.91523153415955 m
# Speed: 41.95 km/h
# New position: 487.1642424930089 m
# Speed: 55.25 km/h
# New position: 476.15249234074895 m
# Speed: 57.583333333333336 km/h
# New position: 478.5788498429218 m
# Speed: 54.2 km/h
# New position: 464.2566981814669 m
# Speed: 59.45 km/h
# New position: 446.45955506266665 m
# Speed: 66.33333333333334 km/h
# New position: 444.4568762838599 m
# Speed: 61.2 km/h
# New position: 447.4599588652145 m
# Speed: 51.4 km/h
# New position: 444.8355541056801 m
# Speed: 57.35 km/h
# New position: 467.9743282685916 m
# Speed: 56.06666666666667 km/h
# New position: 488.91462409360287 m
# Speed: 58.28333333333333 km/h
# New position: 485.8319843313064 m
# Speed: 40.55 km/h
# New position: 511.60932733542694 m
# Speed: 47.78333333333333 km/h
# New position: 514.8691578292346 m
# Speed: 44.75 km/h
# New position: 500.303222766423 m
# Speed: 53.61666666666667 km/h
# New position: 499.12517966017293 m
# Speed: 59.21666666666667 km/h
# New position: 482.1566841605463 m
# Speed: 50.81666666666667 km/h
# New position: 485.26366128873474 m
# Speed: 56.18333333333334 km/h
# New position: 488.320271580083 m
# Speed: 56.88333333333333 km/h
# New position: 511.28284643926736 m
# Speed: 55.25 km/h
# New position: 513.3968503985218 m
# Speed: 61.666666666666664 km/h
# New position: 512.5382838467843 m
# Speed: 52.68333333333334 km/h
# New position: 515.4038359071682 m
# Speed: 52.916666666666664 km/h
# New position: 527.273653543013 m
# Speed: 45.68333333333334 km/h
# New position: 548.5873677586748 m
# Speed: 55.833333333333336 km/h
# New position: 583.702055200043 m
# Speed: 57.93333333333334 km/h
# New position: 582.7117156345417 m
# Speed: 52.333333333333336 km/h
# New position: 592.1173376723302 m
# Speed: 54.666666666666664 km/h
# New position: 608.2427122662868 m
# Speed: 45.68333333333334 km/h
# New position: 611.3769467532173 m
# Speed: 60.5 km/h
# New position: 609.6769664268156 m
# Speed: 48.483333333333334 km/h
# New position: 623.1710478348414 m
# Speed: 46.96666666666667 km/h
# New position: 649.755220097371 m
# Speed: 41.36666666666667 km/h
# New position: 638.4525065936381 m
# Speed: 51.75 km/h
# New position: 642.7470076429015 m
# Speed: 37.28333333333333 km/h
# New position: 619.6480788502184 m
# Speed: 49.18333333333334 km/h
# New position: 592.2167521193085 m
# Speed: 53.266666666666666 km/h
# New position: 594.2779296213914 m
# Speed: 51.4 km/h
# New position: 596.0622785168694 m
# Speed: 53.733333333333334 km/h
# New position: 624.545562353303 m
# Speed: 44.75 km/h
# New position: 610.2168702327141 m
# Speed: 46.85 km/h
# New position: 610.4391334009555 m
# Speed: 41.71666666666667 km/h
# New position: 594.4919993150302 m
# Speed: 51.166666666666664 km/h
# New position: 611.0514722201266 m
# Speed: 57.93333333333334 km/h
# New position: 623.0134134821307 m
# Speed: 60.266666666666666 km/h
# New position: 635.4901238778511 m
# Speed: 49.06666666666667 km/h
# New position: 637.4473210538581 m
# Speed: 50.35 km/h
# New position: 638.0439499162196 m
# Speed: 56.3 km/h
# New position: 638.0568344407144 m
# Speed: 50.11666666666667 km/h
# New position: 647.3137883716649 m
# Speed: 49.766666666666666 km/h
# New position: 643.7909648400972 m
# Speed: 51.166666666666664 km/h
# New position: 669.9994044291191 m
# Speed: 55.483333333333334 km/h
# New position: 666.0421719454173 m
# Speed: 49.65 km/h
# New position: 665.0359076316421 m
# Speed: 38.68333333333334 km/h
# New position: 656.9182357172051 m
# Speed: 45.45 km/h
# New position: 640.7275102680363 m
# Speed: 56.53333333333333 km/h
# New position: 648.5870973851147 m
# Speed: 40.78333333333333 km/h
# New position: 648.2726414211477 m
# Speed: 51.983333333333334 km/h
# New position: 653.5435862278712 m
# Speed: 59.1 km/h
# New position: 660.874336653358 m
# Speed: 46.61666666666667 km/h
# New position: 671.668887544574 m
# Speed: 52.916666666666664 km/h
# New position: 684.1482983448473 m
# Speed: 49.65 km/h
# New position: 713.8375374668311 m
# Speed: 52.1 km/h
# New position: 742.3328269643747 m
# Speed: 53.15 km/h
# New position: 750.2833550070726 m
# Speed: 52.56666666666667 km/h
# New position: 731.1319909211715 m
# Speed: 39.150000000000006 km/h
# New position: 728.4998355704349 m
# Speed: 43.58333333333333 km/h
# New position: 719.9508104706669 m
# Speed: 57.93333333333334 km/h
# New position: 729.7319434240394 m
# Speed: 58.86666666666667 km/h
# New position: 725.3547326253673 m
# Speed: 44.05 km/h
# New position: 719.0363735327958 m
# Speed: 56.53333333333333 km/h
# New position: 726.2069282407647 m
# Speed: 45.33333333333333 km/h
# New position: 738.6496753029427 m
# Speed: 55.13333333333333 km/h
# New position: 741.190274813488 m
# Speed: 41.95 km/h
# New position: 743.4289731994916 m
# Speed: 48.71666666666667 km/h
# New position: 759.7480710412449 m
# Speed: 51.28333333333333 km/h
# New position: 775.6143446818347 m
# Speed: 47.666666666666664 km/h
# New position: 793.0632672389092 m
# Speed: 52.916666666666664 km/h
# New position: 800.5650569331897 m
# Speed: 60.800000000000004 km/h
# New position: 25.416559525504567 m
# Speed: 51.1 km/h
# New position: 32.633158716415394 m
# Speed: 63.6 km/h
# New position: 47.19469792105558 m
# Speed: 50.4 km/h
# New position: 55.74767373192784 m
# Speed: 42.1 km/h
# New position: 72.8166263162463 m
# Speed: 55.1 km/h
# New position: 87.67610603159127 m
# Speed: 51.300000000000004 km/h
# New position: 102.8399773978837 m
# Speed: 56.6 km/h
# New position: 101.1596430523171 m
# Speed: 56.1 km/h
# New position: 111.80034838464226 m
# Speed: 57.400000000000006 km/h
# New position: 134.16182968809525 m
# Speed: 55.7 km/h
# New position: 139.39591413921204 m
# Speed: 61.5 km/h
# New position: 150.9290489819003 m
# Speed: 52.5 km/h
# New position: 149.8068063199187 m
# Speed: 73.0 km/h
# New position: 184.28505338844573 m
# Speed: 63.0 km/h
# New position: 177.90382255556185 m
# Speed: 58.0 km/h
# New position: 184.82595157568758 m
# Speed: 57.7 km/h
# New position: 181.56408554772838 m
# Speed: 51.2 km/h
# New position: 215.38051920848775 m
# Speed: 59.2 km/h
# New position: 248.53292582734278 m
# Speed: 64.5 km/h
# New position: 247.655116689322 m
# Speed: 52.6 km/h
# New position: 262.19356897524636 m
# Speed: 57.5 km/h
# New position: 260.6643943255581 m
# Speed: 56.900000000000006 km/h
# New position: 275.5825439752936 m
# Speed: 49.800000000000004 km/h
# New position: 291.5634915145358 m
# Speed: 55.1 km/h
# New position: 288.4526162145579 m
# Speed: 59.800000000000004 km/h
# New position: 302.55778251783806 m
# Speed: 52.2 km/h
# New position: 313.7196532411243 m
# Speed: 57.900000000000006 km/h
# New position: 320.4673632661036 m
# Speed: 55.300000000000004 km/h
# New position: 322.01715128651875 m
# Speed: 60.1 km/h
# New position: 329.70268002527644 m
# Speed: 55.5 km/h
# New position: 342.1971338061796 m
# Speed: 53.5 km/h
# New position: 367.8122609974961 m
# Speed: 51.7 km/h
# New position: 368.450781401608 m
# Speed: 49.1 km/h
# New position: 379.1147400031238 m
# Speed: 50.1 km/h
# New position: 369.2665845086459 m
# Speed: 52.7 km/h
# New position: 376.06226758267974 m
# Speed: 61.900000000000006 km/h
# New position: 388.36267083555987 m
# Speed: 55.400000000000006 km/h
# New position: 394.0196396785318 m
# Speed: 61.800000000000004 km/h
# New position: 406.230458847183 m
# Speed: 64.9 km/h
# New position: 446.12634104851315 m
# Speed: 48.6 km/h
# New position: 451.1584941157801 m
# Speed: 55.2 km/h
# New position: 460.0965081303928 m
# Speed: 50.300000000000004 km/h
# New position: 464.298134577533 m
# Speed: 62.0 km/h
# New position: 506.48298717838304 m
# Speed: 42.6 km/h
# New position: 497.3179432591047 m
# Speed: 58.6 km/h
# New position: 519.7925306104 m
# Speed: 50.6 km/h
# New position: 525.5288150377006 m
# Speed: 55.400000000000006 km/h
# New position: 545.944094197316 m
# Speed: 59.5 km/h
# New position: 557.8263340932949 m
# Speed: 58.6 km/h
# New position: 548.4633923590123 m
# Speed: 48.7 km/h
# New position: 532.4864794644684 m
# Speed: 49.9 km/h
# New position: 550.5476300784803 m
# Speed: 55.5 km/h
# New position: 559.0990404961705 m
# Speed: 55.0 km/h
# New position: 560.90002728672 m
# Speed: 59.400000000000006 km/h
# New position: 569.1186577570472 m
# Speed: 63.0 km/h
# New position: 583.0453277465128 m
# Speed: 49.7 km/h
# New position: 591.8460181734663 m
# Speed: 58.1 km/h
# New position: 596.1028700650506 m
# Speed: 57.5 km/h
# New position: 600.716190748304 m
# Speed: 64.7 km/h
# New position: 607.0893074912415 m
# Speed: 39.0 km/h
# New position: 611.1415685728364 m
# Speed: 40.900000000000006 km/h
# New position: 596.0971550111091 m
# Speed: 52.0 km/h
# New position: 593.9569083182416 m
# Speed: 57.400000000000006 km/h
# New position: 591.3287881156264 m
# Speed: 52.4 km/h
# New position: 599.6123017663616 m
# Speed: 57.400000000000006 km/h
# New position: 604.689277150336 m
# Speed: 58.5 km/h
# New position: 608.1486104149874 m
# Speed: 49.4 km/h
# New position: 590.3376626854284 m
# Speed: 39.400000000000006 km/h
# New position: 576.5496218626647 m
# Speed: 51.5 km/h
# New position: 575.5657389426624 m
# Speed: 53.300000000000004 km/h
# New position: 580.4071647832835 m
# Speed: 45.900000000000006 km/h
# New position: 582.8156896369095 m
# Speed: 53.300000000000004 km/h
# New position: 594.1340713307904 m
# Speed: 49.800000000000004 km/h
# New position: 579.3958834651555 m
# Speed: 53.0 km/h
# New position: 595.764221111446 m
# Speed: 52.9 km/h
# New position: 585.0259099209821 m
# Speed: 59.6 km/h
# New position: 586.2518451042567 m
# Speed: 51.9 km/h
# New position: 583.3345685542666 m
# Speed: 41.0 km/h
# New position: 577.2080438870255 m
# Speed: 52.5 km/h
# New position: 584.353879006288 m
# Speed: 44.900000000000006 km/h
# New position: 591.7910674022711 m
# Speed: 51.5 km/h
# New position: 557.2381254077092 m
# Speed: 41.6 km/h
# New position: 534.3537134617975 m
# Speed: 46.6 km/h
# New position: 525.963137370246 m
# Speed: 62.6 km/h
# New position: 525.1715845042183 m
# Speed: 47.300000000000004 km/h
# New position: 526.4285932355899 m
# Speed: 52.800000000000004 km/h
# New position: 536.4794396542572 m
# Speed: 36.900000000000006 km/h
# New position: 533.8676580314193 m
# Speed: 57.0 km/h
# New position: 542.2429910348188 m
# Speed: 53.2 km/h
# New position: 539.8858584042031 m
# Speed: 48.0 km/h
# New position: 513.3577861103736 m
# Speed: 49.6 km/h
# New position: 529.7914489516993 m
# Speed: 58.2 km/h
# New position: 512.3173964962983 m
# Speed: 54.6 km/h
# New position: 537.8109951917124 m
# Speed: 51.4 km/h
# New position: 525.0980575285486 m
# Speed: 57.6 km/h
# New position: 541.8763991338388 m
# Speed: 62.300000000000004 km/h
# New position: 542.470646955878 m
# Speed: 56.900000000000006 km/h
# New position: 564.1094110648764 m
# Speed: 48.4 km/h
# New position: 563.2527451140312 m
# Speed: 55.300000000000004 km/h
# New position: 575.1005795706076 m
# Speed: 52.9 km/h
# New position: 557.3072219153391 m
# Speed: 55.0 km/h
# New position: 577.2906686760393 m
# Speed: 50.5 km/h
# New position: 571.8073736365319 m
# Speed: 59.7 km/h
# New position: 587.1872785616395 m
# Speed: 47.2 km/h
# New position: 594.2241293595964 m
# Speed: 51.4 km/h
# New position: 579.6867935261442 m
# Speed: 47.9 km/h
# New position: 575.2051515214803 m
# Speed: 59.2 km/h
# New position: 557.4808842155988 m
# Speed: 73.2 km/h
# New position: 540.4277507994686 m
# Speed: 60.5 km/h
# New position: 544.1995544323199 m
# Speed: 52.5 km/h
# New position: 546.9190712474962 m
# Speed: 44.5 km/h
# New position: 536.0587132826139 m
# Speed: 53.900000000000006 km/h
# New position: 552.8954533245328 m
# Speed: 59.300000000000004 km/h
# New position: 548.7189327430738 m
# Speed: 43.7 km/h
# New position: 537.7234387600505 m
# Speed: 58.800000000000004 km/h
# New position: 538.2527019124822 m
# Speed: 55.7 km/h
# New position: 533.2765877604768 m
# Speed: 61.1 km/h
# New position: 552.1404045109084 m
# Speed: 59.6 km/h
# New position: 554.0666395542439 m
# Speed: 46.400000000000006 km/h
# New position: 568.7113305156578 m
# Speed: 57.900000000000006 km/h
# New position: 577.6268519104982 m
# Speed: 58.800000000000004 km/h
# New position: 572.4652071466179 m
# Speed: 59.5 km/h
# New position: 589.6237438194707 m
# Speed: 48.0 km/h
# New position: 605.9081076871129 m
# Speed: 47.7 km/h
# New position: 605.8310376600826 m
# Speed: 58.900000000000006 km/h
# New position: 616.8298142651588 m
# Speed: 48.300000000000004 km/h
# New position: 605.0195943055357 m
# Speed: 57.900000000000006 km/h
# New position: 620.0694026273645 m
# Speed: 50.9 km/h
# New position: 640.7649160942291 m
# Speed: 48.0 km/h
# New position: 647.5821135062262 m
# Speed: 61.6 km/h
# New position: 641.969631079653 m
# Speed: 54.5 km/h
# New position: 627.5732370847668 m
# Speed: 60.300000000000004 km/h
# New position: 632.9141651208477 m
# Speed: 52.6 km/h
# New position: 632.938972109114 m
# Speed: 46.7 km/h
# New position: 647.4558568220167 m
# Speed: 51.800000000000004 km/h
# New position: 650.2573164594131 m
# Speed: 53.2 km/h
# New position: 632.2630750183957 m
# Speed: 51.7 km/h
# New position: 615.5218243474063 m
# Speed: 64.1 km/h
# New position: 615.2454421966568 m
# Speed: 52.0 km/h
# New position: 638.030337408205 m
# Speed: 59.6 km/h
# New position: 655.6740334508653 m
# Speed: 50.1 km/h
# New position: 668.5469839587054 m
# Speed: 58.800000000000004 km/h
# New position: 686.8850636283116 m
# Speed: 63.300000000000004 km/h
# New position: 685.6175322662856 m
# Speed: 48.800000000000004 km/h
# New position: 682.4831602345932 m
# Speed: 69.0 km/h
# New position: 695.862013621031 m
# Speed: 54.400000000000006 km/h
# New position: 700.398869735651 m
# Speed: 43.7 km/h
# New position: 699.7063090511452 m
# Speed: 57.300000000000004 km/h
# New position: 719.1677857416889 m
# Speed: 43.900000000000006 km/h
# New position: 713.8967218754644 m
# Speed: 44.900000000000006 km/h
# New position: 709.8546962684434 m
# Speed: 42.400000000000006 km/h
# New position: 686.9751424157154 m
# Speed: 37.6 km/h
# New position: 687.9757865896556 m
# Speed: 52.1 km/h
# New position: 700.7859433266517 m
# Speed: 51.4 km/h
# New position: 711.562886777707 m
# Speed: 60.1 km/h
# New position: 749.9688908485155 m
# Speed: 46.5 km/h
# New position: 733.6573971414279 m
# Speed: 52.2 km/h
# New position: 714.5088747118151 m
# Speed: 43.8 km/h
# New position: 717.6460917839745 m
# Speed: 49.2 km/h
# New position: 734.8577931460549 m
# Speed: 49.4 km/h
# New position: 720.7064742098067 m
# Speed: 47.4 km/h
# New position: 717.6474629591005 m
# Speed: 44.8 km/h
# New position: 736.921436118813 m
# ...
# Speed: 52.800000000000004 km/h
# New position: 717.0427994754385 m
# Speed: 51.5 km/h
# New position: 711.3031745065773 m
# Speed: 56.400000000000006 km/h
# New position: 702.2814136474173 m
# Speed: 44.900000000000006 km/h
# New position: 689.1307441029257 m
# Speed: 53.0 km/h
# New position: 696.5684116921926 m
# Speed: 53.300000000000004 km/h
# New position: 701.9673072621044 m
# Speed: 61.2 km/h
# New position: 706.1631287459547 m
# Speed: 52.9 km/h
# New position: 710.0291948853675 m
# Speed: 53.5 km/h
# New position: 741.7184115439348 m
# Speed: 46.1 km/h
# New position: 762.9381511938369 m
# Speed: 54.1 km/h
# New position: 768.9084690512964 m
# Speed: 46.2 km/h
# New position: 747.2017822636908 m
# Speed: 52.5 km/h
# New position: 759.6251700011811 m
# Speed: 48.6 km/h
# New position: 766.5423702141356 m
# Speed: 46.7 km/h
# New position: 760.1555006081142 m
# Speed: 55.1 km/h
# New position: 746.7914859728313 m
# Speed: 44.1 km/h
# New position: 723.6648292996402 m
# Speed: 60.1 km/h
# New position: 727.7530535974722 m
# Speed: 42.5 km/h
# New position: 710.8738788010486 m
# Speed: 61.1 km/h
# New position: 699.764033756581 m
# Speed: 58.400000000000006 km/h
# New position: 692.367593765238 m
# Speed: 47.6 km/h
# New position: 690.2500160015875 m
# Speed: 47.4 km/h
# New position: 689.658365452801 m
# Speed: 55.800000000000004 km/h
# New position: 677.4815653073435 m
# Speed: 56.800000000000004 km/h
# New position: 669.8004801665227 m
# Speed: 55.7 km/h
# New position: 666.8611703427423 m
# Speed: 58.300000000000004 km/h
# New position: 678.7286479239123 m
# Speed: 47.6 km/h
# New position: 682.6656404101107 m
# Speed: 56.1 km/h
# New position: 686.3815444950229 m
# Speed: 58.800000000000004 km/h
# New position: 686.5464538060041 m
# Speed: 44.0 km/h
# New position: 673.2121245428344 m
# Speed: 47.800000000000004 km/h
# New position: 649.3861044714265 m
# Speed: 45.2 km/h
# New position: 648.7702802120488 m
# Speed: 50.800000000000004 km/h
# New position: 662.9183948488572 m
# Speed: 59.2 km/h
# New position: 673.34438219543 m
# Speed: 52.9 km/h
# New position: 679.355349896631 m
# Speed: 49.1 km/h
# New position: 677.7861879904225 m
# Speed: 52.7 km/h
# New position: 684.5913000779079 m
# Speed: 57.0 km/h
# New position: 675.9869830563022 m
# Speed: 51.2 km/h
# New position: 698.0294032279152 m
# Speed: 56.2 km/h
# New position: 701.6523047088137 m
# Speed: 53.6 km/h
# New position: 688.9069580214962 m
# Speed: 48.5 km/h
# New position: 701.021666145276 m
# Speed: 46.2 km/h
# New position: 715.4376149649383 m
# Speed: 52.1 km/h
# New position: 709.8823843264847 m
# Speed: 42.3 km/h
# New position: 729.8105338625346 m
# Speed: 52.800000000000004 km/h
# New position: 719.8027012089137 m
# Speed: 53.5 km/h
# New position: 712.9594145189226 m
# Speed: 55.2 km/h
# New position: 701.7036097339098 m
# Speed: 51.7 km/h
# New position: 713.8592694269967 m
# Speed: 61.300000000000004 km/h
# New position: 725.2735711011012 m
# Speed: 45.8 km/h
# New position: 720.0748884562668 m
# Speed: 43.3 km/h
# New position: 728.2476793916438 m
# Speed: 45.7 km/h
# New position: 720.6290776635499 m
# Speed: 48.6 km/h
# New position: 717.5534013729372 m
# Speed: 52.9 km/h
# New position: 739.4011988687953 m
# Speed: 63.900000000000006 km/h
# New position: 719.4445415023779 m
# Speed: 58.7 km/h
# New position: 738.2186762395362 m
# Speed: 50.4 km/h
# New position: 761.767062708298 m
# Speed: 48.6 km/h
# New position: 763.9235784285116 m
# Speed: 49.9 km/h
# New position: 753.3059073917552 m
# Speed: 59.2 km/h
# New position: 754.9173749623297 m
# Speed: 51.2 km/h
# New position: 729.5458335042281 m
# Speed: 57.5 km/h
# New position: 732.57781418085 m
# Speed: 45.0 km/h
# New position: 732.786991465187 m
# Speed: 55.2 km/h
# New position: 733.6218020730608 m
# Speed: 49.300000000000004 km/h
# New position: 723.483908444813 m
# Speed: 53.800000000000004 km/h
# New position: 718.8477549382122 m
# Speed: 48.7 km/h
# New position: 727.6276799192381 m
# Speed: 61.300000000000004 km/h
# New position: 738.4213389215709 m
# Speed: 45.1 km/h
# New position: 725.341448939639 m
# Speed: 48.1 km/h
# New position: 709.0476349118227 m
# Speed: 41.5 km/h
# New position: 712.2676224568932 m
# Speed: 55.1 km/h
# New position: 709.3896371639141 m
# Speed: 40.0 km/h
# New position: 716.6411573748774 m
# Speed: 38.400000000000006 km/h
# New position: 718.4381438825453 m
# Speed: 36.900000000000006 km/h
# New position: 740.1090922814233 m
# Speed: 55.400000000000006 km/h
# New position: 757.4317148009229 m
# Speed: 50.5 km/h
# New position: 748.352919252205 m
# Speed: 51.5 km/h
# New position: 753.5565603722608 m
# Speed: 45.8 km/h
# New position: 757.5459799641394 m
# Speed: 45.8 km/h
# New position: 729.4979769767051 m
# Speed: 56.7 km/h
# New position: 719.1883723299649 m
# Speed: 53.1 km/h
# New position: 724.721593017489 m
# Speed: 46.7 km/h
# New position: 713.5543821522944 m
# Speed: 53.800000000000004 km/h
# New position: 710.4382355790976 m
# Speed: 54.5 km/h
# New position: 709.6619127630014 m
# Speed: 46.1 km/h
# New position: 725.6958059104031 m
# Speed: 44.400000000000006 km/h
# New position: 732.5683857394498 m
# Speed: 65.1 km/h
# New position: 740.1762833953347 m
# Speed: 52.7 km/h
# New position: 756.5189298865353 m
# Speed: 51.7 km/h
# New position: 745.2942470828586 m
# Speed: 45.6 km/h
# New position: 763.8812391340812 m
# Speed: 48.7 km/h
# New position: 780.4090882997575 m
# Speed: 54.2 km/h
# New position: 776.9255504833533 m
# Speed: 46.2 km/h
# New position: 769.593961765504 m
# Speed: 54.300000000000004 km/h
# New position: 784.1426079105244 m
# Speed: 45.1 km/h
# New position: 764.4219770603054 m
# Speed: 60.7 km/h
# New position: 777.0991333197273 m
# Speed: 45.3 km/h
# New position: 789.0830880313953 m
# Speed: 48.6 km/h
# New position: 791.6332864254704 m
# Speed: 45.900000000000006 km/h
# New position: 821.4575374279384 m
# Speed: 63.7375 km/h
# New position: 24.862671873003915 m
# Speed: 64.35 km/h
# New position: 34.139942711494406 m
# Speed: 60.9375 km/h
# New position: 52.54292323109881 m
# Speed: 64.35 km/h
# New position: 61.981957721549875 m
# Speed: 53.849999999999994 km/h
# New position: 87.43331783219764 m
# Speed: 50.0875 km/h
# New position: 108.51409774308021 m
# Speed: 41.95 km/h
# New position: 104.41625005462267 m
# Speed: 54.9 km/h
# New position: 99.73620842895927 m
# Speed: 62.425 km/h
# New position: 128.1580037745568 m
# Speed: 60.412499999999994 km/h
# New position: 141.51452998209334 m
# Speed: 64.4375 km/h
# New position: 147.60649487200817 m
# Speed: 59.8 km/h
# New position: 164.8327899438608 m
# Speed: 55.3375 km/h
# New position: 208.50449125484653 m
# Speed: 64.69999999999999 km/h
# New position: 235.28354676567665 m
# Speed: 52.012499999999996 km/h
# New position: 237.42855038122752 m
# Speed: 61.9875 km/h
# New position: 247.53553153442783 m
# Speed: 54.724999999999994 km/h
# New position: 260.7330816248881 m
# Speed: 59.625 km/h
# New position: 246.35050155132956 m
# Speed: 60.2375 km/h
# New position: 261.01291579912476 m
# Speed: 47.637499999999996 km/h
# New position: 268.3824592669855 m
# Speed: 60.15 km/h
# New position: 264.5965844476134 m
# Speed: 52.625 km/h
# New position: 287.51592253085914 m
# Speed: 61.4625 km/h
# New position: 299.86757325587286 m
# Speed: 54.375 km/h
# New position: 307.9596803874331 m
# Speed: 61.8125 km/h
# New position: 309.9442900347932 m
# Speed: 61.55 km/h
# New position: 313.90299305410133 m
# Speed: 49.2125 km/h
# New position: 300.9332501659276 m
# Speed: 55.3375 km/h
# New position: 293.52273533827184 m
# Speed: 63.824999999999996 km/h
# New position: 293.83831102099765 m
# Speed: 47.9 km/h
# New position: 305.3673096337425 m
# Speed: 48.949999999999996 km/h
# New position: 318.6213295535071 m
# Speed: 57.9625 km/h
# New position: 352.4280482094987 m
# Speed: 53.9375 km/h
# New position: 361.22872604317394 m
# Speed: 47.4625 km/h
# New position: 376.41337364674905 m
# Speed: 56.387499999999996 km/h
# New position: 379.0054433074761 m
# Speed: 55.074999999999996 km/h
# New position: 391.94978221407996 m
# Speed: 63.824999999999996 km/h
# New position: 390.85714548140163 m
# Speed: 55.074999999999996 km/h
# New position: 397.6733115863956 m
# Speed: 53.15 km/h
# New position: 433.2773179390604 m
# Speed: 56.7375 km/h
# New position: 439.23753368969716 m
# Speed: 61.025 km/h
# New position: 461.19837468982473 m
# Speed: 49.2125 km/h
# New position: 473.2030447381129 m
# Speed: 52.1875 km/h
# New position: 480.1678216107078 m
# Speed: 63.2125 km/h
# New position: 471.63192317903946 m
# Speed: 55.599999999999994 km/h
# New position: 462.2745415041355 m
# Speed: 54.9875 km/h
# New position: 483.552890954564 m
# Speed: 51.925 km/h
# New position: 498.55352589357017 m
# Speed: 53.0625 km/h
# New position: 515.5181409235738 m
# Speed: 57.9625 km/h
# New position: 522.7448749511098 m
# Speed: 62.425 km/h
# New position: 552.4995019152344 m
# Speed: 59.275 km/h
# New position: 544.9906871313426 m
# Speed: 51.224999999999994 km/h
# New position: 531.415140987542 m
# Speed: 52.275 km/h
# New position: 519.971629807343 m
# Speed: 54.724999999999994 km/h
# New position: 534.7224025629054 m
# Speed: 50.175 km/h
# New position: 552.9767741336146 m
# Speed: 40.8125 km/h
# New position: 540.1587892432904 m
# Speed: 56.5625 km/h
# New position: 552.4737009744499 m
# Speed: 39.9375 km/h
# New position: 554.1569328266488 m
# Speed: 48.3375 km/h
# New position: 553.669902488714 m
# Speed: 63.3 km/h
# New position: 552.7522428663111 m
# Speed: 58.224999999999994 km/h
# New position: 552.8439303182049 m
# Speed: 59.099999999999994 km/h
# New position: 554.0025852361293 m
# Speed: 61.8125 km/h
# New position: 587.2321252831188 m
# Speed: 59.625 km/h
# New position: 574.9073072137354 m
# Speed: 54.199999999999996 km/h
# New position: 565.0945989187662 m
# Speed: 58.224999999999994 km/h
# New position: 572.6757725895417 m
# Speed: 52.012499999999996 km/h
# New position: 567.1568991954092 m
# Speed: 47.55 km/h
# New position: 579.169920339585 m
# Speed: 54.199999999999996 km/h
# New position: 576.5328072194762 m
# Speed: 49.824999999999996 km/h
# New position: 561.645203599431 m
# Speed: 56.037499999999994 km/h
# New position: 585.1279122575446 m
# Speed: 48.775 km/h
# New position: 601.086140911435 m
# Speed: 45.45 km/h
# New position: 627.485143460221 m
# Speed: 54.025 km/h
# New position: 643.4184937817141 m
# Speed: 48.3375 km/h
# New position: 657.1308589870206 m
# Speed: 46.9375 km/h
# New position: 646.387464813571 m
# Speed: 56.387499999999996 km/h
# New position: 642.529435043497 m
# Speed: 56.474999999999994 km/h
# New position: 658.7141063279613 m
# Speed: 50.262499999999996 km/h
# New position: 650.4754437503923 m
# Speed: 49.474999999999994 km/h
# New position: 660.2450546780768 m
# Speed: 44.75 km/h
# New position: 652.4542356369733 m
# Speed: 51.4 km/h
# New position: 666.3140935109625 m
# Speed: 53.0625 km/h
# New position: 678.8918451806547 m
# Speed: 45.974999999999994 km/h
# New position: 683.8674453560885 m
# Speed: 47.637499999999996 km/h
# New position: 678.6201384925439 m
# Speed: 45.275 km/h
# New position: 684.4525686252828 m
# Speed: 49.125 km/h
# New position: 683.6950111984947 m
# Speed: 52.449999999999996 km/h
# New position: 716.7224810173437 m
# Speed: 50.4375 km/h
# New position: 701.8676319871432 m
# Speed: 56.474999999999994 km/h
# New position: 704.7122393530886 m
# Speed: 41.6875 km/h
# New position: 687.1631126601712 m
# Speed: 58.05 km/h
# New position: 705.6590898149475 m
# Speed: 49.7375 km/h
# New position: 707.5138143968649 m
# Speed: 43.787499999999994 km/h
# New position: 711.7381191379062 m
# Speed: 53.2375 km/h
# New position: 718.0220601425391 m
# Speed: 48.512499999999996 km/h
# New position: 702.7279795410061 m
# Speed: 40.55 km/h
# New position: 688.6074058380265 m
# Speed: 45.974999999999994 km/h
# New position: 700.0304870779033 m
# Speed: 55.162499999999994 km/h
# New position: 704.8990576208813 m
# Speed: 47.199999999999996 km/h
# New position: 703.282707200294 m
# Speed: 56.5625 km/h
# New position: 700.2922608740801 m
# Speed: 58.3125 km/h
# New position: 694.4681400786266 m
# Speed: 53.2375 km/h
# New position: 696.3520730475576 m
# Speed: 54.199999999999996 km/h
# New position: 682.5583453189493 m
# Speed: 49.824999999999996 km/h
# New position: 688.7136112821804 m
# Speed: 54.4625 km/h
# New position: 664.4944057488995 m
# Speed: 48.3375 km/h
# New position: 651.3889138986597 m
# Speed: 45.45 km/h
# New position: 637.6354726898401 m
# Speed: 58.05 km/h
# New position: 629.8703555120837 m
# Speed: 40.8125 km/h
# New position: 645.1362945856063 m
# Speed: 54.1125 km/h
# New position: 663.8407511249573 m
# Speed: 41.599999999999994 km/h
# New position: 694.6802675381062 m
# Speed: 53.5875 km/h
# New position: 706.0319658524076 m
# Speed: 49.824999999999996 km/h
# New position: 712.5259693305112 m
# Speed: 35.912499999999994 km/h
# New position: 705.9565215348628 m
# Speed: 45.974999999999994 km/h
# New position: 685.2578015379444 m
# Speed: 47.199999999999996 km/h
# New position: 685.0919341155687 m
# Speed: 45.45 km/h
# New position: 690.4275529794884 m
# Speed: 50.0875 km/h
# New position: 674.5610720659362 m
# Speed: 55.949999999999996 km/h
# New position: 670.7139561257956 m
# Speed: 66.975 km/h
# New position: 679.0887841702797 m
# Speed: 49.824999999999996 km/h
# New position: 691.743160548334 m
# Speed: 50.525 km/h
# New position: 677.1425844156936 m
# Speed: 56.387499999999996 km/h
# New position: 698.5760125172056 m
# Speed: 59.1875 km/h
# New position: 719.2199876244175 m
# Speed: 49.387499999999996 km/h
# New position: 714.3320175101968 m
# Speed: 51.662499999999994 km/h
# New position: 734.4853733929722 m
# Speed: 43.4375 km/h
# New position: 737.5563419094806 m
# Speed: 44.662499999999994 km/h
# New position: 725.5694924527103 m
# Speed: 53.0625 km/h
# New position: 741.579891450952 m
# Speed: 43.875 km/h
# New position: 729.0833026339817 m
# Speed: 53.324999999999996 km/h
# New position: 751.4324117835391 m
# Speed: 44.224999999999994 km/h
# New position: 734.2005540209709 m
# Speed: 57.699999999999996 km/h
# New position: 746.6046101136498 m
# Speed: 57.4375 km/h
# New position: 737.1143853179868 m
# Speed: 45.0125 km/h
# New position: 747.9173633395264 m
# Speed: 51.925 km/h
# New position: 767.6502585189803 m
# Speed: 49.387499999999996 km/h
# New position: 751.8734509764208 m
# Speed: 49.5625 km/h
# New position: 757.6995307575587 m
# Speed: 42.7375 km/h
# New position: 774.001851760718 m
# Speed: 43.4375 km/h
# New position: 761.1860978907913 m
# Speed: 47.4625 km/h
# New position: 762.6257363016608 m
# Speed: 54.375 km/h
# New position: 772.8038370487911 m
# Speed: 55.3375 km/h
# New position: 758.5733253245797 m
# Speed: 38.0125 km/h
# New position: 777.5877605815692 m
# Speed: 50.262499999999996 km/h
# New position: 782.196252846204 m
# Speed: 48.775 km/h
# New position: 754.3064570383389 m
# Speed: 54.025 km/h
# New position: 754.4939901063711 m
# Speed: 50.6125 km/h
# New position: 758.3622215132771 m
# Speed: 56.474999999999994 km/h
# New position: 775.5824200620909 m
# Speed: 53.2375 km/h
# New position: 772.365091195157 m
# Speed: 42.474999999999994 km/h
# New position: 772.4411073791823 m
# Speed: 50.6125 km/h
# New position: 764.3435412675876 m
# Speed: 40.724999999999994 km/h
# New position: 753.9153195609351 m
# Speed: 53.5 km/h
# New position: 736.1898779889194 m
# Speed: 58.574999999999996 km/h
# New position: 745.7611176292764 m
# Speed: 55.3375 km/h
# New position: 742.43497214684 m
# Speed: 50.787499999999994 km/h
# New position: 740.104042896277 m
# Speed: 52.449999999999996 km/h
# New position: 740.8136436071128 m
# Speed: 45.3625 km/h
# New position: 742.8820098406877 m
# Speed: 55.949999999999996 km/h
# New position: 735.2189984429282 m
# Speed: 37.662499999999994 km/h
# New position: 755.9951431123884 m
# Speed: 44.575 km/h
# New position: 756.0219209977251 m
# Speed: 61.199999999999996 km/h
# New position: 780.6060567755634 m
# Speed: 51.4875 km/h
# New position: 798.2586747323231 m
# Speed: 47.725 km/h
# New position: 786.112873381027 m
# Speed: 47.025 km/h
# New position: 776.5873599428344 m
# Speed: 50.262499999999996 km/h
# New position: 781.4818183297577 m
# Speed: 50.0875 km/h
# New position: 787.0708877199529 m
# Speed: 44.925 km/h
# New position: 776.2262486525188 m
# Speed: 45.8 km/h
# New position: 789.2612040344363 m
# Speed: 55.25 km/h
# New position: 777.336768217944 m
# Speed: 44.575 km/h
# New position: 750.0439211216911 m
# Speed: 55.512499999999996 km/h
# New position: 751.0045588281787 m
# Speed: 54.724999999999994 km/h
# New position: 767.5816230318925 m
# Speed: 47.375 km/h
# New position: 794.2262133465449 m
# Speed: 41.162499999999994 km/h
# New position: 794.3742129104004 m
# Speed: 52.099999999999994 km/h
# New position: 786.4993224517153 m
# Speed: 44.575 km/h
# New position: 770.772434626278 m
# Speed: 61.025 km/h
# New position: 796.580734277855 m
# Speed: 45.974999999999994 km/h
# New position: 807.7346760764132 m

# %%
discr = [d for d in dict.keys()]
elapsed = [t for t in dict.values()]

plt.title(r'Time elapsed for each $d\_discr$')
plt.xlabel(r'$d\_discr$', fontsize=12)
plt.ylabel(r'Time $(s)$', fontsize=12)
plt.plot(discr, elapsed, 'bo')
plt.show()
plt.savefig("elapsed")
