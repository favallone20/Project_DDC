# %% [markdown]
# ### Code for Project 2: "Synthesis of control policies from demonstrations for fully driverless trains"
#
# The setup is as follows: we want to synthesize a policy for a driverless train from expert demonstration data.
#
# The goal is to find a control policy that makes the behavior of the controlled train similar to the one of the demonstrations, i.e. the experts.
#
# The code below provides all the necessary probability functions that you need to successfully complete the tasks.

# %%
import json
import math

import numpy as np
import scipy.stats as stats

from scipy import interpolate
from scipy.interpolate import interpolate
from scipy.interpolate import CubicSpline 

from matplotlib import pyplot as plt

# %% [markdown]
# $\textbf{Kullback-Leibler divergence}$
#
# The general form of Kullback-Leibler divergence is:
#
# $$\mathcal{D}_{KL}(f(x)||g(x)) = \int f(x) \ln{\frac{f(x)}{g(x)} dx}$$
#
# In the case of a normal distribution the Kullback-Leibler divergence becomes:
# $$\mathcal{D}_{KL}(f(x)||g(x)) = \ln{\left(\frac{\sigma_2}{\sigma_1}\right)} + \frac{\sigma_1^2}{2\sigma_2^2} + \frac{(\mu_1 - \mu_2)^2}{\sigma_2^2}- \frac{1}{2}$$
# In the following function DKL is calculated between two Gaussian, coded as an array of [mean, std].

# %%
def DKL_gaussians(g1,g2):
    mu1 = g1[0] #Extracting means
    mu2 = g2[0]
    sigma1 = g1[1] #Extracting stds
    sigma2 = g2[1]
    
    el1 = math.log(sigma1/sigma2) #Calculating the sub-elements of the formula
    el2 = sigma1*sigma1 + (mu1-mu2)*(mu1-mu2)
    el3 = 2*sigma2*sigma2
    
    return(el1 + el2/el3 - 0.5)

# %% [markdown]
# $\textbf{Parameters for} \, f(x_k|x_{k-1}, u_k) \, \text{ and } \, g(x_k|x_{k-1}, u_k)$

# %%
#Parameters for f(x_k|x_{k-1},u_k)
a_c = 0.982
b_c = 0.2591
sigma_c = 13.059

#Parameters for g(x_k|x_{k-1},u_k)
a_e = 0.9811
b_e = 0.2723
sigma_e = 8.811

#Bounds for u (velocity) and x (distance)
v_min = 15
v_max = 85
d_min = 0
d_max = 1500

#Amount of bins (resolution) for u and x
v_discr = 100
d_discr = 100

# %% [markdown]
# $\textbf{Discretization step and axis preparation}$
#
# From all possible states and control input values, from a minimum value to a max value, we sampled $d\_discr$ samples. The discretization step is obtained as:
# \begin{equation*}
#     d\_step = \frac{max - min}{d\_discr}
# \end{equation*}
# Then we compute the horizontal axis taking into account the mean value in each d_step.

# %%
d_step = (d_max-d_min)/d_discr # Discretization step for x
v_step = (v_max-v_min)/v_discr # Discretization step for u

x_axis = [d_min + (i+0.5)*d_step for i in range(d_discr)]
u_axis = [v_min + (j+0.5)*v_step for j in range(v_discr)]

# %% [markdown]
# $\textbf{TASK 1: give a detailed documentation of what this function does and how it fits in the methodology}$
#
# The following function gets the probability mass function of the plant:
# \begin{equation*}
#     f(x_k|x_{k-1}, u_k), \quad g(x_k|x_{k-1}, u_k)
# \end{equation*}
#
# The function parameters $a, b$ represent the linear parameters for the mean, while the function parameter $\sigma$ represents the standard deviation of the pmf.
#
# In particular the mean is obtained as: $$\mu = ax_{k-1} + bu_k$$ For each combination $(x_{k-1}, u_k)$ the pair $[\mu, \sigma]$ is stored in the matrix $res$.

# %%
def getPlant(a, b, sigma):
    # Function for getting the plant (f_x or g_x) from the parameters.
    # The arguments are the linear parameters for the mean and the std.
    # The Gaussians are simply coded as [mean, std] to simplify calculations
    res = np.zeros((d_discr,v_discr,2)) # Initializing the empty array
    for i in range(d_discr): # Iterating over the state space for x_{k-1}
        x_km1 = d_min + (i+0.5)*d_step # Calculating x_{k-1}
        for j in range(v_discr): # Iterating over the action space for u_k
            u_k = v_min + (j+0.5)*v_step  # Calculating u_k
            mu = a*x_km1 + b*u_k # Calculating the average of the Gaussian
            res[i][j] = [mu, sigma] # Adding the Gaussian in [mean, std] form to the array
    return(res)

# %% [markdown]
# $\textbf{TASK 2: plot the probability functions used in the example}$
#
# $\textbf{(below you have the parameters and recall the functions are Gaussians)}$
#
# Through the function $getPlant$ we obtain $f(x_k|x_{k-1}, u_k)$ which is the autonomous train plant and $g(x_k|x_{k-1}, u_k)$ the expert train plant.
#
# Using the lib $stats$ we plot the Gaussian with a specific $[\mu, \sigma]$ obtained by the train plant and the expert plant.

# %%
# f(x_k|x_{k-1}, u_k)
f_x = getPlant(a_c, b_c, sigma_c)

# g(x_k|x_{k-1},u_k)
g_x = getPlant(a_e, b_e, sigma_e)

plt.figure(figsize=(8, 6), dpi=80)
for i in range(0, f_x.shape[1] - 1, 5):
    plt.subplot(2,1,1)
    plt.ylabel(r'Probability', fontsize=12)
    plt.title(r'$f(x_k|x_{k-1}, u_k)$')
    plt.plot(x_axis, stats.norm.pdf(x_axis, f_x[i][i+1][0], f_x[i][i+1][1])) #f_x[xkm1][uk][0] = μ, f_x[xkm1][uk][1]= σ
    plt.subplot(2,1,2)
    plt.xlabel(r'Position $(m)$', fontsize=12)
    plt.ylabel(r'Probability', fontsize=12)
    plt.title(r'$g(x_k|x_{k-1}, u_k)$')
    plt.plot(x_axis, stats.norm.pdf(x_axis, g_x[i][i+1][0], g_x[i][i+1][1])) #g_x[xkm1][uk][0] = μ, g_x[xkm1][uk][1]= σ
# Out:
# /tmp/ipykernel_7225/1998613519.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,1,1)
# /tmp/ipykernel_7225/1998613519.py:13: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,1,2)

# %% [markdown]
# With the following code we want to demonstrate that in a given state (e.g. state=98) it is more likely to go back instead of going forward.
#
# We have used a table to represent what are the states that we can reach starting from the current state (column "Index"), what is the range of meters encoded with the same index state (column "Range meters") and how many control inputs allow to reach it (column "Number of occurrences").
#
# In this way, we have demonstrated why our system can't reach the final destination.

# %%
from prettytable import PrettyTable 

state = 98
header = ['Index', 'Range meters', 'Number occurrences']

table = PrettyTable(header)
mydict = {}

for i in range(v_discr):
    index = str(round(f_x[state][i][0]/d_step))
    if index not in mydict:
        mydict[index] = []
    mydict[index].append('%.3f'%(f_x[state][i][0]))

for i in mydict.keys():
    x = len(mydict[i])
    if x != 0: 
        mydict[i] = "["+str(mydict[i][0]) +", " +str(mydict[i][-1])+"]"
        table.add_row([i, mydict[i],x])
    
print(table)
# Out:
# +-------+----------------------+--------------------+
# | Index |     Range meters     | Number occurrences |
# +-------+----------------------+--------------------+
# |   97  | [1454.882, 1462.500] |         43         |
# |   98  | [1462.681, 1472.838] |         57         |
# +-------+----------------------+--------------------+

# %% [markdown]
# $\textbf{TASK3: find out why this function is needed}$
#
# $means["x"]$ and $means["y"]$ are arrays of values used to approximate some function $g(u_k|x_{k-1})$.
#
# The interpolation operation is needed to define a function to identify new points of a discrete set from the dataset.

# %%
# Data sources
f1 = open('train_mean.json')
f2 = open('train_std.json')

means = json.load(f1)
std = json.load(f2)

# We approximate the mean function using the arrays means['x'] and means['y'].
fmean = interpolate.interp1d(means['x'],means['y'], fill_value="extrapolate")

# We approximate the std function using the arrays std['x'] and std['y'].
fstd = interpolate.interp1d(std['x'],std['y'], fill_value="extrapolate")

#We call the function fmean, passing as a parameter the array x_axis, to calculate the value of new points.
example_means = fmean(x_axis)
#We call the function fstd, passing as a parameter the array x_axis, to calculate the value of new points.  
example_std = fstd(x_axis)

# %% [markdown]
# $\textbf{TASK4: plot sample trajectories from the files below. What is the train doing?}$
#
# We plot the trajectory of the expert $g(u_k|x_{k-1})$, showing also the variance around the mean value of the trajectory. We call the function fmean, passing as a parameter the array $x\_axis$, to calculate the value of new points.
# The simulation starts with the train in motion.
# From the plot we observed that the train is decreasing its speed.
#
# In addition, we have used a different interpolation, but the result is the same.

# %%
#Another way to do the interpolation
fmean_c = CubicSpline(means['x'],means['y'])
fstd_c = CubicSpline(std['x'],std['y'])

example_means_c = fmean_c(x_axis)
example_std_c = fstd_c(x_axis)

#Plot with CubicSpline
plt.figure(figsize=(8, 6), dpi=80)
plt.subplots_adjust(hspace=.5 )
plt.subplot(2, 1, 1)
plt.title("CubicSpline")
plt.plot(x_axis, example_means_c)
plt.xlabel(r'Position $(m)$', fontsize=12)
plt.ylabel(r'Velocity $(km/h)$', fontsize=12)
plt.fill_between(x_axis, example_means_c - example_std_c, example_means_c + example_std_c, color='b', alpha = 0.1)

#Plot with Interp1d
plt.subplot(2, 1, 2)
plt.title("Interp1d")
plt.plot(x_axis, example_means)
plt.xlabel(r'Position $(m)$', fontsize=12)
plt.ylabel(r'Velocity $(km/h)$', fontsize=12)
plt.fill_between(x_axis, example_means - example_std, example_means + example_std, color='r', alpha = 0.1)

# %% [markdown]
# This function samples from a Gaussian with specified parameters

# %%
def sample_gaussian(mu, sigma, Ax):
    #where Ax is the horizontal axis
    pmf = [0]*len(Ax) #Initializing the pmf
    for i in range(len(Ax)): #Iterating over the state space to calculate the elements of the pmf
        pmf[i] = np.exp(-0.5*((Ax[i]-mu)/sigma)**2) #Using the explicit formula for the Gaussian
                                            #The multiplicative factor is omitted as the pmf will be normalized
    S = np.sum(pmf) #Calculating the sum for normalization
    return([x/S for x in pmf])

# %% [markdown]
# This function is used to return the target policy given a state.

# %%
def ex_policy(x_km1):
    indX = int(x_km1//d_step) #Calculating the index to which corresponds x_km1
    return(sample_gaussian(example_means[indX],example_std[indX],u_axis))

# %% [markdown]
# This function is used to return the target policy given a index.

# %%
def target_policy(indX):
    #Returns the target policy for the state index indX
    return(sample_gaussian(example_means[indX],example_std[indX],u_axis))

# %% [markdown]
# $\textbf{TASK 5: write down the formal problem statement for the control problem considered within this project}$
#
# Assuming to know pdf $f(x_k|x_{k-1}, u_k)$ and have available $\textit{demonstration dataset }$ $\Delta^e_{0:N}$ the goal is to synthesize, from such dataset, a control policy that could be used by the agent to solve the same task as the one being demonstrated.
# It is formally intended that the agent has to behave like the demostrator. As we have already seen, we can have the following probabilistic description:
#
# $$g(\Delta^e_{0:N}) = g(x_0)\prod_{k=1}^N g(x_k, u_k|x_{k-1}) = g(x_0)\prod_{k=1}^N g(x_k| u_k, x_{k-1})g(u_k|x_{k-1})$$
# The problem of synthesizing control policies that make the behavior of the system similar to the behavior seen in the demonstration dataset can be formalized as the following decision-making problem:
#
#
# $\textit{Find the policy}$ $\{f_{k|k-1}^{(u), *}\}_{1:N}$ $\textit{such that:}$
#
# $$\{f_{k|k-1}^{(u), *}\}_{1:N} \in \arg\min_{ \{f_{k|k-1}^{(u)}\}_{1:N}} \mathcal{D}_{KL}(f_{0:N}||g_{0:N})$$
# $$s.t. \quad f^{(u)}_{k|k-1} \in \mathcal{D}, \forall k \in 1:N$$
# Minimizing $\mathcal{D}_{KL}(f_{0:N}||g_{0:N})$ means making $f_{0:N}$ as similar as possible to $g_{0:N}$.
#
# The optimal policy which resolve the problem is given, at each time step $k$ from:
# $$f^{(u),*}_{k|k-1} =  g^{(u)}_{k|k-1} \dfrac{exp\left(-\mathcal{D}_{KL}(f^{(x)}_{k+1|k}||g^{(x)}_{k+1|k})+ \mathbb{E}_{f^{(x)}_{k+1|k}}[\gamma_k(X_k)]\right)}{\int g^{(x)}_{k+1|k} exp\left(-\mathcal{D}_{KL}(f^{(x)}_{k+1|k}||g^{(x)}_{k+1|k})+ \mathbb{E}_{f^{(x)}_{k+1|k}}[\gamma_k(X_k)]\right) du_k}$$
#
# in which $\gamma_k$ is obtained by a $\textbf{backward recursion}$:
# $$ \gamma_k(x_k) = \ln{\mathbb{E}_{g^{(u)}_{k+1|k}} [exp(-\mathcal{D}_{KL}(f^{(x)}_{k+1|k}||g^{(x)}_{k+1|k})]}$$

# %% [markdown]
# $\textbf{TASK 6: write here the code to solve the control problem (greedy version)}$
#
# We have implemented runFPD function for implementing the algorithm for control from demonstrations. In addition, it is included the receding horizon version of the algorithm.

# %%
def runFPD(xStart, tHor=0):
    #Runs the control from demos algorithm, assuming the agent is at state xStart (given as an index!) with a time horizon tHor
    #Initializing zero gamma function
    gamma = np.zeros(d_discr)
    # If time horizon is greater than 0 we consider the states from the min between (xStart + time horizon -1) and 
    # (d_discr-2) (in order to not exceed the dimension of the array) to (xStart + 1) 
    if tHor > 0: 
        stateAtTime = list(range(min(xStart + tHor-1, d_discr - 2), xStart, -1)) # remember xStart = xkm1
    # Else we don't take into account the future states, but we consider only the next time step
    else: 
        stateAtTime = [] 
    
    # We calculate gamma from (xStart + time horizon -1) to (xStart + 1)
    for xk, uk in zip(stateAtTime, stateAtTime):
        # We initialize an auxiliary array, which we will use to calculate gamma_k(x_k) 
        gammaArray = np.zeros(v_discr)
        # We get f(x_{k+1}|x_k,u_{k+1}) in [mean, std] form
        plant = f_x[xk][uk+1] 
        # We get g(x_{k+1}|x_k,u_{k+1}) in [mean, std] form
        target_plant = g_x[xk][uk+1]
         # We build the array with the exp of the DKL of the 'future' plants
        gammaArray[uk+1] = np.exp(-DKL_gaussians(plant, target_plant))
        # Finally we calculate gamma, which is the log of the expectation of our auxiliary array
        gamma[xk] = np.log(np.dot(target_policy(xk),gammaArray)) 
    
    #previous state x_(k-1)
    xkm1 = xStart  
    policy = np.zeros(v_discr)
    # We extract the corresponding target policy, g(u_k|x_{k-1}) 
    target_pol = target_policy(xkm1) 
    for u in range(v_discr): 
        # We get f(x_{k}|x_{k - 1}, u_k) 
        plant = f_x[xkm1][u] 
        # We get g(x_{k}|x_{k - 1}, u_k) 
        target_plant = g_x[xkm1][u]
        # We sample plant for expectations
        plant_sampled = sample_gaussian(plant[0],plant[1],x_axis) 
        policy[u] = target_pol[u]*np.exp(-DKL_gaussians(plant, target_plant) + np.dot(plant_sampled,gamma))
    # We calculate the integral
    S = np.sum(policy)
    # We return the normalized result 
    return([elt/S for elt in policy])

# %% [markdown]
# $\textbf{TASK 7: Write a routine to validate your code}$
#
# To validate our code we have written a simulation of the closed loop system starting from the initial state.

# %%
def simulation():

    position = []
    speed = []
    x = 0

    while(x < d_discr - 20): #half-way termination condition
        policy = runFPD(x) # We get the optimal policy
        u = np.random.choice(range(v_discr),p=policy) # We choose a random index u from the policy according to the distribution of it.
        plant = f_x[x][u] # We get the mean and the standard deviation of the next state given the actual state and the current input.
        # We get the new state from the Gaussian plant
        trueX = np.random.normal(plant[0],plant[1])
        # We compute the state index and verify if it is inside the range [0, d_discr - 1]
        x = round((trueX-d_min)/d_step)
        
        x = max(x, 0)
        
        # We compute the value of input from the input index
        trueU = v_min + v_step*u
        
        position.append(trueX)
        speed.append(trueU)

        print("Speed: " + str(trueU) + " km/h")
        print("New position: " + str(trueX) + " m")

    plt.figure(figsize=(8, 6), dpi=80)
    plt.subplot(2,1,1)
    plt.title("Simulation of the closed loop (Agent Policy)")
    plt.ylabel(r'Position $(m)$', fontsize=12)
    plt.plot(position)
    
    plt.subplot(2,1,2)
    plt.xlabel(r'Time $(s)$', fontsize=12)
    plt.ylabel(r'Velocity $(km/h)$', fontsize=12)
    plt.plot(speed)
    plt.show()

simulation()
# Out:
# Speed: 56.3 km/h
# New position: 6.997406173936476 m
# Speed: 63.3 km/h
# New position: 23.059544595872158 m
# Speed: 66.8 km/h
# New position: 46.06408059181457 m
# Speed: 65.4 km/h
# New position: 81.7467049337997 m
# Speed: 57.0 km/h
# New position: 92.77500187071824 m
# Speed: 64.0 km/h
# New position: 98.0114121164924 m
# Speed: 52.8 km/h
# New position: 113.18785365098732 m
# Speed: 57.0 km/h
# New position: 137.25573485197597 m
# Speed: 41.599999999999994 km/h
# New position: 149.39059729462107 m
# Speed: 62.599999999999994 km/h
# New position: 165.4074552859605 m
# Speed: 57.0 km/h
# New position: 171.5010501472704 m
# Speed: 60.5 km/h
# New position: 172.05608631171472 m
# Speed: 57.0 km/h
# New position: 173.2243762639712 m
# Speed: 59.099999999999994 km/h
# New position: 195.16034195743356 m
# Speed: 54.9 km/h
# New position: 225.23290632107194 m
# Speed: 60.5 km/h
# New position: 243.19888530827353 m
# Speed: 58.4 km/h
# New position: 274.7965683081378 m
# Speed: 52.099999999999994 km/h
# New position: 288.58159991295656 m
# Speed: 47.9 km/h
# New position: 295.88900219062657 m
# Speed: 55.599999999999994 km/h
# New position: 287.8536968338507 m
# Speed: 51.4 km/h
# New position: 303.69067955724455 m
# Speed: 48.599999999999994 km/h
# New position: 301.7422250121267 m
# Speed: 48.599999999999994 km/h
# New position: 353.8445002598137 m
# Speed: 50.699999999999996 km/h
# New position: 364.9320271823616 m
# Speed: 58.4 km/h
# New position: 374.90677546406283 m
# Speed: 57.699999999999996 km/h
# New position: 391.0466763848891 m
# Speed: 56.3 km/h
# New position: 404.1042013305042 m
# Speed: 65.4 km/h
# New position: 413.9787120264207 m
# Speed: 65.4 km/h
# New position: 413.740197251105 m
# Speed: 54.9 km/h
# New position: 423.27714088376223 m
# Speed: 62.599999999999994 km/h
# New position: 435.9339299610918 m
# Speed: 53.5 km/h
# New position: 453.4506578796966 m
# Speed: 45.099999999999994 km/h
# New position: 464.76516377583675 m
# Speed: 55.599999999999994 km/h
# New position: 499.60522882829 m
# Speed: 53.5 km/h
# New position: 499.661863672224 m
# Speed: 56.3 km/h
# New position: 522.3155410474575 m
# Speed: 52.099999999999994 km/h
# New position: 513.9260821672722 m
# Speed: 54.9 km/h
# New position: 524.6294569978761 m
# Speed: 43.7 km/h
# New position: 537.155297454207 m
# Speed: 63.3 km/h
# New position: 560.5916534400556 m
# Speed: 43.7 km/h
# New position: 557.9084254046035 m
# Speed: 50.0 km/h
# New position: 582.6959793962184 m
# Speed: 43.7 km/h
# New position: 600.1893622629078 m
# Speed: 56.3 km/h
# New position: 621.2151504100901 m
# Speed: 53.5 km/h
# New position: 622.5020379252228 m
# Speed: 49.3 km/h
# New position: 623.0712467254309 m
# Speed: 66.1 km/h
# New position: 666.7198530907889 m
# Speed: 37.4 km/h
# New position: 671.0158946710835 m
# Speed: 53.5 km/h
# New position: 679.8500579505499 m
# Speed: 57.699999999999996 km/h
# New position: 661.9466971716905 m
# Speed: 48.599999999999994 km/h
# New position: 664.9627674887206 m
# Speed: 47.199999999999996 km/h
# New position: 661.4976366211075 m
# Speed: 54.9 km/h
# New position: 657.2742351794827 m
# Speed: 44.4 km/h
# New position: 657.2245341817033 m
# Speed: 45.099999999999994 km/h
# New position: 677.2710428645643 m
# Speed: 41.599999999999994 km/h
# New position: 691.0358626467743 m
# Speed: 49.3 km/h
# New position: 684.4954820744512 m
# Speed: 51.4 km/h
# New position: 721.9541835414004 m
# Speed: 62.599999999999994 km/h
# New position: 729.6551018418837 m
# Speed: 53.5 km/h
# New position: 757.9023575429069 m
# Speed: 55.599999999999994 km/h
# New position: 777.4308830162588 m
# Speed: 56.3 km/h
# New position: 780.8609503483437 m
# Speed: 40.9 km/h
# New position: 789.8075253928398 m
# Speed: 50.0 km/h
# New position: 814.1921283641095 m
# Speed: 52.8 km/h
# New position: 839.5837696926989 m
# Speed: 42.3 km/h
# New position: 833.8068746998799 m
# Speed: 50.699999999999996 km/h
# New position: 836.4156148662939 m
# Speed: 47.199999999999996 km/h
# New position: 837.9303921824446 m
# Speed: 55.599999999999994 km/h
# New position: 847.2075164223486 m
# Speed: 47.199999999999996 km/h
# New position: 823.5063580411279 m
# Speed: 38.099999999999994 km/h
# New position: 826.0225183338301 m
# Speed: 57.699999999999996 km/h
# New position: 824.3674087503919 m
# Speed: 56.3 km/h
# New position: 832.547886048005 m
# Speed: 47.9 km/h
# New position: 854.3634117400709 m
# Speed: 51.4 km/h
# New position: 866.1291704288934 m
# Speed: 54.9 km/h
# New position: 880.0820157854777 m
# Speed: 54.199999999999996 km/h
# New position: 875.2401610602443 m
# Speed: 46.5 km/h
# New position: 862.7584461563081 m
# Speed: 51.4 km/h
# New position: 878.335874538293 m
# Speed: 45.099999999999994 km/h
# New position: 886.3773889308441 m
# Speed: 45.099999999999994 km/h
# New position: 881.5042473167247 m
# Speed: 51.4 km/h
# New position: 881.5595232782802 m
# Speed: 56.3 km/h
# New position: 878.0984220704595 m
# Speed: 36.7 km/h
# New position: 876.4546805808756 m
# Speed: 45.099999999999994 km/h
# New position: 861.0179036715243 m
# Speed: 51.4 km/h
# New position: 861.3037182830125 m
# Speed: 43.0 km/h
# New position: 858.2233416924564 m
# Speed: 50.0 km/h
# New position: 863.2206622023397 m
# Speed: 51.4 km/h
# New position: 872.1546368254579 m
# Speed: 31.099999999999998 km/h
# New position: 851.2925124638801 m
# Speed: 61.9 km/h
# New position: 873.6663149565592 m
# Speed: 50.699999999999996 km/h
# New position: 882.688093284171 m
# Speed: 45.8 km/h
# New position: 895.4953916521168 m
# Speed: 36.7 km/h
# New position: 893.415060375531 m
# Speed: 51.4 km/h
# New position: 923.1619961388633 m
# Speed: 47.9 km/h
# New position: 933.3076900043584 m
# Speed: 55.599999999999994 km/h
# New position: 929.2718756629508 m
# Speed: 50.699999999999996 km/h
# New position: 929.8015115667948 m
# Speed: 59.8 km/h
# New position: 920.6256637068084 m
# Speed: 43.0 km/h
# New position: 903.032350820886 m
# Speed: 45.099999999999994 km/h
# New position: 903.887449432999 m
# Speed: 40.9 km/h
# New position: 889.8556386019903 m
# Speed: 57.699999999999996 km/h
# New position: 868.8388095018464 m
# Speed: 34.599999999999994 km/h
# New position: 905.1442816845655 m
# Speed: 54.199999999999996 km/h
# New position: 912.2228506231801 m
# Speed: 51.4 km/h
# New position: 918.1877388193026 m
# Speed: 49.3 km/h
# New position: 922.115850966667 m
# Speed: 55.599999999999994 km/h
# New position: 921.2625326018979 m
# Speed: 42.3 km/h
# New position: 906.2930274034343 m
# Speed: 50.0 km/h
# New position: 912.5429830143593 m
# Speed: 62.599999999999994 km/h
# New position: 936.324483219771 m
# Speed: 55.599999999999994 km/h
# New position: 949.7598884092259 m
# Speed: 40.9 km/h
# New position: 947.3553916024176 m
# Speed: 53.5 km/h
# New position: 919.8397974004921 m
# Speed: 48.599999999999994 km/h
# New position: 908.1224158542285 m
# Speed: 40.2 km/h
# New position: 915.3781334426429 m
# Speed: 43.7 km/h
# New position: 937.5167005590969 m
# Speed: 52.099999999999994 km/h
# New position: 957.7520399741462 m
# Speed: 38.8 km/h
# New position: 937.9968704661519 m
# Speed: 50.0 km/h
# New position: 953.9456893564143 m
# Speed: 46.5 km/h
# New position: 976.6615683932886 m
# Speed: 40.9 km/h
# New position: 980.4689066766966 m
# Speed: 46.5 km/h
# New position: 970.291228912833 m
# Speed: 49.3 km/h
# New position: 957.0926832206225 m
# Speed: 36.7 km/h
# New position: 971.6959520518354 m
# Speed: 43.0 km/h
# New position: 964.0560400078273 m
# Speed: 40.2 km/h
# New position: 956.2530513635775 m
# Speed: 59.8 km/h
# New position: 962.747601691329 m
# Speed: 49.3 km/h
# New position: 939.8144993482322 m
# Speed: 48.599999999999994 km/h
# New position: 953.4954009810301 m
# Speed: 44.4 km/h
# New position: 956.3432074311485 m
# Speed: 42.3 km/h
# New position: 993.2875264812097 m
# Speed: 46.5 km/h
# New position: 1010.962138038822 m
# Speed: 31.799999999999997 km/h
# New position: 998.764898278239 m
# Speed: 57.0 km/h
# New position: 1012.28147929833 m
# Speed: 50.699999999999996 km/h
# New position: 984.9773966516531 m
# Speed: 38.8 km/h
# New position: 990.612620423031 m
# Speed: 48.599999999999994 km/h
# New position: 969.817379798903 m
# Speed: 43.0 km/h
# New position: 970.8135418660974 m
# Speed: 47.9 km/h
# New position: 980.8607476329702 m
# Speed: 47.199999999999996 km/h
# New position: 968.4817914191051 m
# Speed: 44.4 km/h
# New position: 985.8020143884778 m
# Speed: 38.8 km/h
# New position: 987.1547721911106 m
# Speed: 41.599999999999994 km/h
# New position: 1001.0495120025047 m
# Speed: 47.9 km/h
# New position: 992.1127286880551 m
# Speed: 41.599999999999994 km/h
# New position: 968.1712474086848 m
# Speed: 52.099999999999994 km/h
# New position: 973.4085792297471 m
# Speed: 47.9 km/h
# New position: 971.8584468200793 m
# Speed: 43.7 km/h
# New position: 992.3621640945984 m
# Speed: 54.9 km/h
# New position: 985.8338691039282 m
# Speed: 48.599999999999994 km/h
# New position: 995.1919882535914 m
# Speed: 43.7 km/h
# New position: 968.6084889361016 m
# Speed: 45.099999999999994 km/h
# New position: 963.9319868667114 m
# Speed: 43.0 km/h
# New position: 971.429571662205 m
# Speed: 33.9 km/h
# New position: 979.3708757959353 m
# Speed: 45.099999999999994 km/h
# New position: 976.6792697018229 m
# Speed: 46.5 km/h
# New position: 982.776689470636 m
# Speed: 48.599999999999994 km/h
# New position: 1008.332434001411 m
# Speed: 33.9 km/h
# New position: 1000.8227864963693 m
# Speed: 54.199999999999996 km/h
# New position: 975.0394461045225 m
# Speed: 47.9 km/h
# New position: 971.1134406010337 m
# Speed: 40.2 km/h
# New position: 977.7688014920654 m
# Speed: 43.7 km/h
# New position: 969.1029598408628 m
# Speed: 48.599999999999994 km/h
# New position: 972.8774940258037 m
# Speed: 52.099999999999994 km/h
# New position: 966.7917929092717 m
# Speed: 54.9 km/h
# New position: 953.3157950000275 m
# Speed: 51.4 km/h
# New position: 954.0064728508938 m
# Speed: 44.4 km/h
# New position: 956.1288876349836 m
# Speed: 48.599999999999994 km/h
# New position: 960.1726259138728 m
# Speed: 46.5 km/h
# New position: 984.8751012411183 m
# Speed: 38.099999999999994 km/h
# New position: 970.8265809385815 m
# Speed: 41.599999999999994 km/h
# New position: 990.7946762150476 m
# Speed: 50.0 km/h
# New position: 973.5647369335991 m
# Speed: 50.699999999999996 km/h
# New position: 974.1331863526633 m
# Speed: 55.599999999999994 km/h
# New position: 967.1759093260719 m
# Speed: 53.5 km/h
# New position: 958.4321159983791 m
# Speed: 45.8 km/h
# New position: 955.5705166548322 m
# Speed: 53.5 km/h
# New position: 970.721741353587 m
# Speed: 42.3 km/h
# New position: 976.7573294655923 m
# Speed: 44.4 km/h
# New position: 958.8734924683815 m
# Speed: 46.5 km/h
# New position: 952.1090951920085 m
# Speed: 40.9 km/h
# New position: 947.0304984956664 m
# Speed: 52.8 km/h
# New position: 948.765692402041 m
# Speed: 47.9 km/h
# New position: 935.3218400487851 m
# Speed: 42.3 km/h
# New position: 918.4754308149984 m
# Speed: 53.5 km/h
# New position: 910.4230588849226 m
# Speed: 45.099999999999994 km/h
# New position: 916.5971272514565 m
# Speed: 53.5 km/h
# New position: 914.8754126801695 m
# Speed: 54.199999999999996 km/h
# New position: 937.7371512960624 m
# Speed: 53.5 km/h
# New position: 968.5562255998204 m
# Speed: 38.099999999999994 km/h
# New position: 966.1225157052806 m
# Speed: 43.0 km/h
# New position: 933.0147461096885 m
# Speed: 35.3 km/h
# New position: 900.9483574993179 m
# Speed: 36.7 km/h
# New position: 908.5063163307183 m
# Speed: 50.0 km/h
# New position: 916.9102560139116 m
# Speed: 54.199999999999996 km/h
# New position: 919.4935044427413 m
# Speed: 49.3 km/h
# New position: 923.8200005529658 m
# Speed: 44.4 km/h
# New position: 919.8668153686081 m
# Speed: 45.099999999999994 km/h
# New position: 899.4074421747865 m
# Speed: 49.3 km/h
# New position: 904.0468110285757 m
# Speed: 55.599999999999994 km/h
# New position: 895.2765921827414 m
# Speed: 47.9 km/h
# New position: 884.8254398212983 m
# Speed: 43.7 km/h
# New position: 884.5738771468054 m
# Speed: 50.699999999999996 km/h
# New position: 913.6562029361268 m
# Speed: 52.8 km/h
# New position: 903.2342776357895 m
# Speed: 44.4 km/h
# New position: 896.1048743576707 m
# Speed: 42.3 km/h
# New position: 904.2718960206969 m
# Speed: 64.0 km/h
# New position: 913.2183242345689 m
# Speed: 54.199999999999996 km/h
# New position: 928.2731060333666 m
# Speed: 45.099999999999994 km/h
# New position: 915.382568102788 m
# Speed: 44.4 km/h
# New position: 921.4131768154134 m
# Speed: 47.9 km/h
# New position: 904.4228041816148 m
# Speed: 51.4 km/h
# New position: 889.9747239835925 m
# Speed: 46.5 km/h
# New position: 908.1649053907126 m
# Speed: 51.4 km/h
# New position: 923.6604598309531 m
# Speed: 39.5 km/h
# New position: 929.1870548967007 m
# Speed: 47.9 km/h
# New position: 941.225782260311 m
# Speed: 49.3 km/h
# New position: 955.2648521342314 m
# Speed: 41.599999999999994 km/h
# New position: 957.5568629666827 m
# Speed: 46.5 km/h
# New position: 944.8810859834657 m
# Speed: 43.7 km/h
# New position: 955.7134141953683 m
# Speed: 42.3 km/h
# New position: 945.5629960313232 m
# Speed: 54.199999999999996 km/h
# New position: 945.3563080086187 m
# Speed: 45.8 km/h
# New position: 944.2315453996973 m
# Speed: 49.3 km/h
# New position: 961.6345026152226 m
# Speed: 47.9 km/h
# New position: 954.0008871029796 m
# Speed: 51.4 km/h
# New position: 964.464988460604 m
# Speed: 56.3 km/h
# New position: 967.4251861538618 m
# Speed: 46.5 km/h
# New position: 968.1304958089763 m
# Speed: 43.7 km/h
# New position: 972.3191579394885 m
# Speed: 49.3 km/h
# New position: 968.8896520299063 m
# Speed: 60.5 km/h
# New position: 975.3899610239743 m
# Speed: 36.7 km/h
# New position: 964.5675225001733 m
# Speed: 55.599999999999994 km/h
# New position: 953.9221452285135 m
# Speed: 55.599999999999994 km/h
# New position: 967.9189771567304 m
# Speed: 44.4 km/h
# New position: 976.0404926962318 m
# Speed: 47.9 km/h
# New position: 977.6863598299672 m
# Speed: 52.8 km/h
# New position: 980.728829844736 m
# Speed: 50.699999999999996 km/h
# New position: 992.9627961291966 m
# Speed: 48.599999999999994 km/h
# New position: 1007.8303238405799 m
# Speed: 45.099999999999994 km/h
# New position: 1022.1893463427202 m
# Speed: 41.599999999999994 km/h
# New position: 1012.3175626312817 m
# Speed: 46.5 km/h
# New position: 1023.0213486685171 m
# Speed: 43.0 km/h
# New position: 985.0056262625668 m
# Speed: 52.099999999999994 km/h
# New position: 980.838985102713 m
# Speed: 59.099999999999994 km/h
# New position: 995.7975910940762 m
# Speed: 40.2 km/h
# New position: 981.0542471939063 m
# Speed: 43.0 km/h
# New position: 957.7349628179663 m
# Speed: 33.2 km/h
# New position: 952.9172316491789 m
# Speed: 49.3 km/h
# New position: 979.1004832162879 m
# Speed: 39.5 km/h
# New position: 979.2894209975183 m
# Speed: 42.3 km/h
# New position: 977.050923633574 m
# Speed: 54.9 km/h
# New position: 987.1195747842388 m
# Speed: 52.099999999999994 km/h
# New position: 975.9574309450949 m
# Speed: 49.3 km/h
# New position: 988.4526849802417 m
# Speed: 43.0 km/h
# New position: 988.9472805398194 m
# Speed: 45.099999999999994 km/h
# New position: 985.6387750490566 m
# Speed: 45.8 km/h
# New position: 986.6469854944166 m
# Speed: 38.8 km/h
# New position: 1003.0975539086264 m
# Speed: 42.3 km/h
# New position: 1015.2189096220419 m
# Speed: 51.4 km/h
# New position: 1016.6386604069995 m
# Speed: 44.4 km/h
# New position: 1017.3421803898648 m
# Speed: 45.099999999999994 km/h
# New position: 1032.4280539654821 m
# Speed: 59.099999999999994 km/h
# New position: 1046.7645019577424 m
# Speed: 43.0 km/h
# New position: 1059.4880966890896 m
# Speed: 54.199999999999996 km/h
# New position: 1062.4593417447038 m
# Speed: 47.199999999999996 km/h
# New position: 1051.3208099975352 m
# Speed: 49.3 km/h
# New position: 1038.093791083481 m
# Speed: 47.9 km/h
# New position: 1052.1607732938987 m
# Speed: 36.7 km/h
# New position: 1069.5513683539118 m
# Speed: 50.0 km/h
# New position: 1038.831092623029 m
# Speed: 47.199999999999996 km/h
# New position: 1025.2282215924904 m
# Speed: 38.8 km/h
# New position: 992.2460582809522 m
# Speed: 52.099999999999994 km/h
# New position: 996.4079802304523 m
# Speed: 35.3 km/h
# New position: 995.8677791412279 m
# Speed: 54.9 km/h
# New position: 980.2995182213938 m
# Speed: 54.9 km/h
# New position: 964.6244413309191 m
# Speed: 40.9 km/h
# New position: 978.0069478621617 m
# Speed: 45.099999999999994 km/h
# New position: 990.8110751445321 m
# Speed: 53.5 km/h
# New position: 987.0087214831678 m
# Speed: 54.9 km/h
# New position: 1007.1992298666012 m
# Speed: 57.0 km/h
# New position: 1012.4182275363505 m
# Speed: 44.4 km/h
# New position: 986.6995063967972 m
# Speed: 47.199999999999996 km/h
# New position: 991.9312041101505 m
# Speed: 57.0 km/h
# New position: 991.0791789079733 m
# Speed: 43.0 km/h
# New position: 995.1438227508166 m
# Speed: 43.7 km/h
# New position: 990.2305767106993 m
# Speed: 43.0 km/h
# New position: 978.933931005606 m
# Speed: 50.0 km/h
# New position: 974.6075250407391 m
# Speed: 47.9 km/h
# New position: 960.5971916384425 m
# Speed: 48.599999999999994 km/h
# New position: 976.9946732488064 m
# Speed: 41.599999999999994 km/h
# New position: 993.5686576292939 m
# Speed: 48.599999999999994 km/h
# New position: 993.2396818406255 m
# Speed: 47.9 km/h
# New position: 995.9993070019298 m
# Speed: 39.5 km/h
# New position: 1001.6643747946376 m
# Speed: 47.9 km/h
# New position: 992.5871454254018 m
# Speed: 51.4 km/h
# New position: 1007.0016988924682 m
# Speed: 55.599999999999994 km/h
# New position: 1008.0541182248248 m
# Speed: 40.2 km/h
# New position: 1009.166186126316 m
# Speed: 45.099999999999994 km/h
# New position: 986.5151975317995 m
# Speed: 47.9 km/h
# New position: 991.7122354489424 m
# Speed: 49.3 km/h
# New position: 979.2573569589629 m
# Speed: 41.599999999999994 km/h
# New position: 971.1765056717711 m
# Speed: 53.5 km/h
# New position: 988.4396707867414 m
# Speed: 45.099999999999994 km/h
# New position: 994.8505443739214 m
# Speed: 44.4 km/h
# New position: 987.3873314547023 m
# Speed: 45.099999999999994 km/h
# New position: 981.0483798083825 m
# Speed: 41.599999999999994 km/h
# New position: 991.4110142096091 m
# Speed: 45.8 km/h
# New position: 996.7774112072941 m
# Speed: 40.9 km/h
# New position: 974.5569094177811 m
# Speed: 42.3 km/h
# New position: 962.5870908364922 m
# Speed: 38.8 km/h
# New position: 934.2386416346086 m
# Speed: 40.2 km/h
# New position: 920.7762292393941 m
# Speed: 55.599999999999994 km/h
# New position: 912.4571983383255 m
# Speed: 59.099999999999994 km/h
# New position: 922.7563591602858 m
# Speed: 52.099999999999994 km/h
# New position: 933.3532513272067 m
# Speed: 37.4 km/h
# New position: 921.89538697972 m
# Speed: 48.599999999999994 km/h
# New position: 923.9301069266006 m
# Speed: 44.4 km/h
# New position: 935.028646959393 m
# Speed: 41.599999999999994 km/h
# New position: 929.3757266480478 m
# Speed: 52.8 km/h
# New position: 926.815885792275 m
# Speed: 54.9 km/h
# New position: 923.7933546830097 m
# Speed: 37.4 km/h
# New position: 946.6476745673697 m
# Speed: 47.9 km/h
# New position: 952.5575243136554 m
# Speed: 52.099999999999994 km/h
# New position: 952.3894223254563 m
# Speed: 45.099999999999994 km/h
# New position: 949.2615568369475 m
# Speed: 47.9 km/h
# New position: 958.8507574699715 m
# Speed: 44.4 km/h
# New position: 966.7549922961989 m
# Speed: 39.5 km/h
# New position: 953.4053388591014 m
# Speed: 39.5 km/h
# New position: 957.4986130256012 m
# Speed: 51.4 km/h
# New position: 980.1580512156295 m
# Speed: 38.8 km/h
# New position: 952.7754251779 m
# Speed: 45.8 km/h
# New position: 959.8114168310371 m
# Speed: 39.5 km/h
# New position: 952.598776501235 m
# Speed: 46.5 km/h
# New position: 981.7775120464312 m
# Speed: 59.099999999999994 km/h
# New position: 989.7590819893954 m
# Speed: 54.199999999999996 km/h
# New position: 976.7201454839327 m
# Speed: 40.9 km/h
# New position: 964.7486925331038 m
# Speed: 38.8 km/h
# New position: 961.8665074640967 m
# Speed: 52.8 km/h
# New position: 967.8659494729405 m
# Speed: 50.699999999999996 km/h
# New position: 975.0458695590795 m
# Speed: 40.9 km/h
# New position: 975.996709909116 m
# Speed: 47.199999999999996 km/h
# New position: 969.2596380631544 m
# Speed: 49.3 km/h
# New position: 987.1766268934492 m
# Speed: 47.9 km/h
# New position: 985.3860019300365 m
# Speed: 58.4 km/h
# New position: 984.7786412569626 m
# Speed: 40.2 km/h
# New position: 983.4116079322663 m
# Speed: 47.9 km/h
# New position: 987.6646442784958 m
# Speed: 51.4 km/h
# New position: 974.7646864342798 m
# Speed: 43.0 km/h
# New position: 950.5998109601271 m
# Speed: 44.4 km/h
# New position: 936.922011146831 m
# Speed: 40.2 km/h
# New position: 900.8660214074503 m
# Speed: 56.3 km/h
# New position: 899.5346455150806 m
# Speed: 47.199999999999996 km/h
# New position: 903.1061730867857 m
# Speed: 39.5 km/h
# New position: 885.7131397178388 m
# Speed: 44.4 km/h
# New position: 889.328267471198 m
# Speed: 50.0 km/h
# New position: 882.4349913000535 m
# Speed: 45.099999999999994 km/h
# New position: 896.1266704539106 m
# Speed: 57.0 km/h
# New position: 900.8586491898214 m
# Speed: 47.199999999999996 km/h
# New position: 919.5897834950619 m
# Speed: 53.5 km/h
# New position: 916.420647289837 m
# Speed: 42.3 km/h
# New position: 911.7217840718487 m
# Speed: 47.9 km/h
# New position: 909.2666955186504 m
# Speed: 47.9 km/h
# New position: 936.8201629426143 m
# Speed: 40.9 km/h
# New position: 952.2425760372761 m
# Speed: 50.0 km/h
# New position: 947.7215837525566 m
# Speed: 45.8 km/h
# New position: 944.6701088519937 m
# Speed: 38.099999999999994 km/h
# New position: 950.3643341829102 m
# Speed: 52.8 km/h
# New position: 953.3089310397486 m
# Speed: 48.599999999999994 km/h
# New position: 966.7838675630755 m
# Speed: 36.7 km/h
# New position: 984.4466347640762 m
# Speed: 47.199999999999996 km/h
# New position: 1000.4383061887698 m
# Speed: 47.199999999999996 km/h
# New position: 1025.2358883807085 m
# Speed: 43.0 km/h
# New position: 1032.9422210848763 m
# Speed: 56.3 km/h
# New position: 1060.122556790179 m
# Speed: 51.4 km/h
# New position: 1060.5359796738483 m
# Speed: 36.7 km/h
# New position: 1059.978845729429 m
# Speed: 58.4 km/h
# New position: 1061.8406889309144 m
# Speed: 46.5 km/h
# New position: 1061.0056578320489 m
# Speed: 43.0 km/h
# New position: 1088.4371664643406 m
# Speed: 50.0 km/h
# New position: 1073.3421487392936 m
# Speed: 36.7 km/h
# New position: 1069.4804707125384 m
# Speed: 54.199999999999996 km/h
# New position: 1073.303528042458 m
# Speed: 41.599999999999994 km/h
# New position: 1067.4157167657286 m
# Speed: 51.4 km/h
# New position: 1074.8480320608064 m
# Speed: 39.5 km/h
# New position: 1061.2063395803993 m
# Speed: 43.0 km/h
# New position: 1089.561680398391 m
# Speed: 44.4 km/h
# New position: 1079.4622451771215 m
# Speed: 40.9 km/h
# New position: 1094.3509477724979 m
# Speed: 45.8 km/h
# New position: 1101.7930340169858 m
# Speed: 50.699999999999996 km/h
# New position: 1085.0063620402138 m
# Speed: 42.3 km/h
# New position: 1068.193632691515 m
# Speed: 52.099999999999994 km/h
# New position: 1060.1944863226777 m
# Speed: 38.099999999999994 km/h
# New position: 1047.5257874680447 m
# Speed: 38.8 km/h
# New position: 1047.4270898674656 m
# Speed: 44.4 km/h
# New position: 1054.846054066859 m
# Speed: 42.3 km/h
# New position: 1055.8149224844367 m
# Speed: 37.4 km/h
# New position: 1069.9879213826623 m
# Speed: 50.0 km/h
# New position: 1078.2624042938528 m
# Speed: 52.099999999999994 km/h
# New position: 1085.7116821446796 m
# Speed: 43.7 km/h
# New position: 1074.5520062266985 m
# Speed: 46.5 km/h
# New position: 1081.105554750851 m
# Speed: 57.699999999999996 km/h
# New position: 1083.267815916254 m
# Speed: 62.599999999999994 km/h
# New position: 1098.444423004681 m
# Speed: 56.3 km/h
# New position: 1084.5830709405611 m
# Speed: 41.599999999999994 km/h
# New position: 1070.2224743428774 m
# Speed: 34.599999999999994 km/h
# New position: 1066.716454764667 m
# Speed: 50.699999999999996 km/h
# New position: 1064.9200987572058 m
# Speed: 47.9 km/h
# New position: 1057.5453230488345 m
# Speed: 51.4 km/h
# New position: 1067.0378588417125 m
# Speed: 43.7 km/h
# New position: 1060.9716765324574 m
# Speed: 42.3 km/h
# New position: 1086.4482453656315 m
# Speed: 47.9 km/h
# New position: 1076.2230835071523 m
# Speed: 48.599999999999994 km/h
# New position: 1076.524244937097 m
# Speed: 46.5 km/h
# New position: 1076.673778765019 m
# Speed: 43.0 km/h
# New position: 1068.9924540735315 m
# Speed: 51.4 km/h
# New position: 1050.3642318258176 m
# Speed: 41.599999999999994 km/h
# New position: 1055.5025547478142 m
# Speed: 47.199999999999996 km/h
# New position: 1045.5381612828853 m
# Speed: 38.8 km/h
# New position: 1030.1832286958204 m
# Speed: 44.4 km/h
# New position: 1044.3148924248196 m
# Speed: 40.2 km/h
# New position: 1045.9793499946986 m
# Speed: 40.2 km/h
# New position: 1045.0249757578815 m
# Speed: 39.5 km/h
# New position: 1044.6875507464438 m
# Speed: 45.099999999999994 km/h
# New position: 1046.2116465494496 m
# Speed: 47.199999999999996 km/h
# New position: 1050.5259102325645 m
# Speed: 37.4 km/h
# New position: 1051.1093302091904 m
# Speed: 48.599999999999994 km/h
# New position: 1044.257733622043 m
# Speed: 57.0 km/h
# New position: 1057.7972893401823 m
# Speed: 47.9 km/h
# New position: 1074.8840974195546 m
# Speed: 43.7 km/h
# New position: 1076.091715460538 m
# Speed: 43.0 km/h
# New position: 1082.5618382091845 m
# Speed: 45.8 km/h
# New position: 1085.3451298426496 m
# Speed: 40.9 km/h
# New position: 1075.2832571708068 m
# Speed: 47.9 km/h
# New position: 1093.0663264411467 m
# Speed: 50.699999999999996 km/h
# New position: 1095.6797689328232 m
# Speed: 43.0 km/h
# New position: 1101.8910712682436 m
# Speed: 34.599999999999994 km/h
# New position: 1099.3369884250485 m
# Speed: 49.3 km/h
# New position: 1088.5930548741192 m
# Speed: 52.8 km/h
# New position: 1110.737897308801 m
# Speed: 47.9 km/h
# New position: 1096.6803675126491 m
# Speed: 43.7 km/h
# New position: 1084.9073263151524 m
# Speed: 44.4 km/h
# New position: 1097.6317025728958 m
# Speed: 46.5 km/h
# New position: 1088.2117695489192 m
# Speed: 43.0 km/h
# New position: 1103.6100828488295 m
# Speed: 56.3 km/h
# New position: 1101.3523245728143 m
# Speed: 52.099999999999994 km/h
# New position: 1096.458657690407 m
# Speed: 54.9 km/h
# New position: 1099.17214951717 m
# Speed: 47.9 km/h
# New position: 1077.3905350560851 m
# Speed: 44.4 km/h
# New position: 1074.1120138810563 m
# Speed: 45.8 km/h
# New position: 1067.1030810280652 m
# Speed: 41.599999999999994 km/h
# New position: 1076.1587294264525 m
# Speed: 35.3 km/h
# New position: 1087.3782638642977 m
# Speed: 50.0 km/h
# New position: 1075.1544716696483 m
# Speed: 44.4 km/h
# New position: 1079.1607542710037 m
# Speed: 34.599999999999994 km/h
# New position: 1070.0075385334344 m
# Speed: 57.0 km/h
# New position: 1077.278814351441 m
# Speed: 46.5 km/h
# New position: 1083.3870536426773 m
# Speed: 38.8 km/h
# New position: 1065.041463317119 m
# Speed: 40.2 km/h
# New position: 1067.599582710524 m
# Speed: 48.599999999999994 km/h
# New position: 1079.4079857532333 m
# Speed: 40.2 km/h
# New position: 1070.8144693913932 m
# Speed: 45.8 km/h
# New position: 1059.0300848203199 m
# Speed: 56.3 km/h
# New position: 1072.7511360815442 m
# Speed: 39.5 km/h
# New position: 1088.060385406562 m
# Speed: 50.0 km/h
# New position: 1092.8954371309403 m
# Speed: 47.9 km/h
# New position: 1101.7492481822799 m
# Speed: 51.4 km/h
# New position: 1089.6480497747134 m
# Speed: 38.8 km/h
# New position: 1103.928728018617 m
# Speed: 51.4 km/h
# New position: 1130.0287238303006 m
# Speed: 55.599999999999994 km/h
# New position: 1149.5509633238044 m
# Speed: 58.4 km/h
# New position: 1163.1556952897836 m
# Speed: 38.099999999999994 km/h
# New position: 1178.4452739905503 m
# Speed: 37.4 km/h
# New position: 1167.8495108797897 m
# Speed: 50.699999999999996 km/h
# New position: 1152.7796623302372 m
# Speed: 43.0 km/h
# New position: 1155.6420071145571 m
# Speed: 43.0 km/h
# New position: 1181.1825994835106 m
# Speed: 49.3 km/h
# New position: 1195.0636599127247 m

# %% [markdown]
# $\textbf{TASK 8: evaluate how the computation times change depending on the discretization}$
#
# We have seen that the computational effort increases with the decreasing of the
# discretization step or, likewise, the increasing in the number of samples.
